# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import cv2
import numpy as np
from scipy.ndimage import label
import matplotlib.pyplot as plt
from tqdm import tqdm

# --------------------------
# ABFA Core
# --------------------------

def detect_active_pixels(frame, background_frames, k=3):
    G_mean = np.mean(background_frames, axis=0)
    G_std = np.std(background_frames, axis=0)
    threshold = G_mean + k * G_std
    active = (frame > threshold).astype(np.uint8)
    return active

def connected_components(active_pixels):
    labeled, num_features = label(active_pixels)
    return labeled, num_features

def filter_blobs(labeled_img, sensor_height=2.0):
    min_cells = int(20 / sensor_height)
    max_cells = int(60 / sensor_height)
    valid_count = 0
    for label_id in np.unique(labeled_img):
        if label_id == 0: continue
        count = np.sum(labeled_img == label_id)
        if min_cells <= count <= max_cells:
            valid_count += 1
    return valid_count

def abfa_pipeline(frame, background_frames, sensor_height=2.0):
    active = detect_active_pixels(frame, background_frames)
    labeled, _ = connected_components(active)
    people_count = filter_blobs(labeled, sensor_height)
    return people_count, active, labeled

# --------------------------
 #Dataset Loader
# --------------------------

def load_images_from_folder(folder, max_images=None, resize_shape=(32, 32)):
    images = []
    for filename in sorted(os.listdir(folder)):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            path = os.path.join(folder, filename)
            img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
            if img is not None:
                img = cv2.resize(img, resize_shape)
                images.append((filename, img))
            if max_images and len(images) >= max_images:
                break
    return images

#  Run on Dataset


dataset_path = "/content/drive/MyDrive/DataCollection"
resize_shape = (32, 32)

# Use some frames from class "1" as background
bg_folder = os.path.join(dataset_path, "1")
background_frames = [img for _, img in load_images_from_folder(bg_folder, max_images=5, resize_shape=resize_shape)]
background_frames = np.array(background_frames)  # shape: (5, 32, 32)

results = []
print("\nRunning ABFA on dataset...\n")

for folder in sorted(os.listdir(dataset_path)):
    folder_path = os.path.join(dataset_path, folder)
    if not os.path.isdir(folder_path): continue
    if not folder.isdigit(): continue

    gt_label = int(folder)
    images = load_images_from_folder(folder_path, resize_shape=resize_shape)

    for filename, frame in tqdm(images, desc=f"Processing class {folder}"):
        pred, _, _ = abfa_pipeline(frame, background_frames)
        results.append((filename, gt_label, pred))

# --------------------------
# 📊 Report Results
# --------------------------

correct = sum(1 for _, gt, pred in results if gt == pred)
total = len(results)

print(f"\n✅ Accuracy: {correct}/{total} = {correct/total:.2%}")

print("\n🔍 Mismatches:")
for filename, gt, pred in results:
    if gt != pred:
        print(f"{filename}: GT={gt}, Pred={pred}")
# Out:
# Running ABFA on dataset...
# Processing class 1: 100%|██████████| 384/384 [00:00<00:00, 1221.75it/s]
# Processing class 10: 100%|██████████| 208/208 [00:00<00:00, 2609.37it/s]
# Processing class 11: 100%|██████████| 288/288 [00:00<00:00, 1835.74it/s]
# Processing class 12: 100%|██████████| 244/244 [00:00<00:00, 2700.42it/s]
# Processing class 13: 100%|██████████| 196/196 [00:00<00:00, 2479.19it/s]
# Processing class 14: 100%|██████████| 240/240 [00:00<00:00, 2767.68it/s]
# Processing class 15: 100%|██████████| 256/256 [00:00<00:00, 2977.31it/s]
# Processing class 2: 100%|██████████| 320/320 [00:00<00:00, 1616.25it/s]
# Processing class 3: 100%|██████████| 416/416 [00:00<00:00, 3766.73it/s]
# Processing class 4: 100%|██████████| 272/272 [00:00<00:00, 1281.00it/s]
# Processing class 5: 100%|██████████| 204/204 [00:00<00:00, 1676.97it/s]
# Processing class 6: 100%|██████████| 184/184 [00:00<00:00, 2567.08it/s]
# Processing class 7: 100%|██████████| 288/288 [00:00<00:00, 2660.02it/s]
# Processing class 8: 100%|██████████| 248/248 [00:00<00:00, 1907.56it/s]
# Processing class 9: 100%|██████████| 304/304 [00:00<00:00, 2215.78it/s]
# ✅ Accuracy: 559/4052 = 13.80%
#
# 🔍 Mismatches:
# 10.png: GT=1, Pred=0
# 100.png: GT=1, Pred=0
# 100_flipped.jpg: GT=1, Pred=0
# 100_flipped_flipped.jpg: GT=1, Pred=0
# 100_flipped_flipped_flipped.jpg: GT=1, Pred=0
# 102.png: GT=1, Pred=0
# 102_flipped.jpg: GT=1, Pred=0
# 102_flipped_flipped.jpg: GT=1, Pred=0
# 102_flipped_flipped_flipped.jpg: GT=1, Pred=0
# 103.png: GT=1, Pred=2
# 103_flipped.jpg: GT=1, Pred=2
# 103_flipped_flipped.jpg: GT=1, Pred=2
# 103_flipped_flipped_flipped.jpg: GT=1, Pred=2
# 105.png: GT=1, Pred=5
# 105_flipped.jpg: GT=1, Pred=2
# 105_flipped_flipped.jpg: GT=1, Pred=4
# 105_flipped_flipped_flipped.jpg: GT=1, Pred=2
# 10_flipped.jpg: GT=1, Pred=2
# 10_flipped_flipped.jpg: GT=1, Pred=0
# 10_flipped_flipped_flipped.jpg: GT=1, Pred=2
# 11.png: GT=1, Pred=0
# 11_flipped_flipped.jpg: GT=1, Pred=0
# 12.png: GT=1, Pred=0
# 12_flipped.jpg: GT=1, Pred=2
# 12_flipped_flipped.jpg: GT=1, Pred=0
# 12_flipped_flipped_flipped.jpg: GT=1, Pred=2
# 13.png: GT=1, Pred=0
# 13_flipped.jpg: GT=1, Pred=2
# 13_flipped_flipped.jpg: GT=1, Pred=0
# 13_flipped_flipped_flipped.jpg: GT=1, Pred=2
# 14.png: GT=1, Pred=0
# 14_flipped.jpg: GT=1, Pred=2
# 14_flipped_flipped.jpg: GT=1, Pred=0
# 14_flipped_flipped_flipped.jpg: GT=1, Pred=2
# 15.png: GT=1, Pred=0
# 15_flipped.jpg: GT=1, Pred=3
# 15_flipped_flipped.jpg: GT=1, Pred=0
# 15_flipped_flipped_flipped.jpg: GT=1, Pred=3
# 16.png: GT=1, Pred=0
# 16_flipped.jpg: GT=1, Pred=2
# 16_flipped_flipped.jpg: GT=1, Pred=0
# 16_flipped_flipped_flipped.jpg: GT=1, Pred=2
# 17.png: GT=1, Pred=0
# 17_flipped.jpg: GT=1, Pred=2
# 17_flipped_flipped.jpg: GT=1, Pred=0
# 17_flipped_flipped_flipped.jpg: GT=1, Pred=2
# 18.png: GT=1, Pred=0
# 18_flipped.jpg: GT=1, Pred=4
# 18_flipped_flipped.jpg: GT=1, Pred=0
# 18_flipped_flipped_flipped.jpg: GT=1, Pred=4
# 24.png: GT=1, Pred=3
# 24_flipped.jpg: GT=1, Pred=5
# 24_flipped_flipped.jpg: GT=1, Pred=2
# 24_flipped_flipped_flipped.jpg: GT=1, Pred=5
# 25.png: GT=1, Pred=3
# 25_flipped.jpg: GT=1, Pred=4
# 25_flipped_flipped.jpg: GT=1, Pred=3
# 25_flipped_flipped_flipped.jpg: GT=1, Pred=3
# 26.png: GT=1, Pred=3
# 26_flipped.jpg: GT=1, Pred=3
# 26_flipped_flipped.jpg: GT=1, Pred=3
# 26_flipped_flipped_flipped.jpg: GT=1, Pred=3
# 28_flipped.jpg: GT=1, Pred=2
# 28_flipped_flipped_flipped.jpg: GT=1, Pred=2
# 30.png: GT=1, Pred=0
# 30_flipped_flipped.jpg: GT=1, Pred=0
# 31.png: GT=1, Pred=5
# 31_flipped.jpg: GT=1, Pred=3
# 31_flipped_flipped.jpg: GT=1, Pred=5
# 31_flipped_flipped_flipped.jpg: GT=1, Pred=3
# 32.png: GT=1, Pred=3
# 32_flipped_flipped.jpg: GT=1, Pred=4
# 34.png: GT=1, Pred=0
# 34_flipped_flipped.jpg: GT=1, Pred=0
# 35.png: GT=1, Pred=0
# 35_flipped_flipped.jpg: GT=1, Pred=0
# 36_flipped.jpg: GT=1, Pred=0
# 36_flipped_flipped_flipped.jpg: GT=1, Pred=0
# 38.png: GT=1, Pred=2
# 38_flipped.jpg: GT=1, Pred=2
# 38_flipped_flipped.jpg: GT=1, Pred=2
# 38_flipped_flipped_flipped.jpg: GT=1, Pred=2
# 39.png: GT=1, Pred=2
# 39_flipped_flipped.jpg: GT=1, Pred=2
# 4.png: GT=1, Pred=0
# 40.png: GT=1, Pred=0
# 41.png: GT=1, Pred=0
# 41_flipped.jpg: GT=1, Pred=0
# 41_flipped_flipped.jpg: GT=1, Pred=0
# 41_flipped_flipped_flipped.jpg: GT=1, Pred=0
# 42.png: GT=1, Pred=0
# 42_flipped_flipped.jpg: GT=1, Pred=0
# 44.png: GT=1, Pred=2
# 44_flipped.jpg: GT=1, Pred=2
# 44_flipped_flipped.jpg: GT=1, Pred=2
# 44_flipped_flipped_flipped.jpg: GT=1, Pred=2
# 45.png: GT=1, Pred=2
# 45_flipped.jpg: GT=1, Pred=2
# 45_flipped_flipped.jpg: GT=1, Pred=2
# 45_flipped_flipped_flipped.jpg: GT=1, Pred=2
# 46_flipped_flipped.jpg: GT=1, Pred=2
# 47.png: GT=1, Pred=2
# 47_flipped_flipped.jpg: GT=1, Pred=2
# 48.png: GT=1, Pred=4
# 48_flipped.jpg: GT=1, Pred=4
# 48_flipped_flipped.jpg: GT=1, Pred=4
# 48_flipped_flipped_flipped.jpg: GT=1, Pred=4
# 49.png: GT=1, Pred=3
# 49_flipped.jpg: GT=1, Pred=5
# 49_flipped_flipped.jpg: GT=1, Pred=3
# 49_flipped_flipped_flipped.jpg: GT=1, Pred=4
# 4_flipped_flipped.jpg: GT=1, Pred=0
# 5.png: GT=1, Pred=0
# 50.png: GT=1, Pred=0
# 50_flipped.jpg: GT=1, Pred=0
# 50_flipped_flipped.jpg: GT=1, Pred=0
# 50_flipped_flipped_flipped.jpg: GT=1, Pred=0
# 51.png: GT=1, Pred=2
# 51_flipped.jpg: GT=1, Pred=3
# 51_flipped_flipped_flipped.jpg: GT=1, Pred=4
# 52.png: GT=1, Pred=2
# 52_flipped.jpg: GT=1, Pred=3
# 52_flipped_flipped.jpg: GT=1, Pred=2
# 52_flipped_flipped_flipped.jpg: GT=1, Pred=3
# 53.png: GT=1, Pred=2
# 53_flipped_flipped.jpg: GT=1, Pred=2
# 55_flipped.jpg: GT=1, Pred=2
# 56.png: GT=1, Pred=0
# 56_flipped.jpg: GT=1, Pred=0
# 56_flipped_flipped.jpg: GT=1, Pred=0
# 56_flipped_flipped_flipped.jpg: GT=1, Pred=0
# 57.png: GT=1, Pred=2
# 57_flipped.jpg: GT=1, Pred=2
# 57_flipped_flipped.jpg: GT=1, Pred=2
# 59.png: GT=1, Pred=2
# 59_flipped.jpg: GT=1, Pred=3
# 59_flipped_flipped.jpg: GT=1, Pred=2
# 59_flipped_flipped_flipped.jpg: GT=1, Pred=3
# 5_flipped.jpg: GT=1, Pred=3
# 5_flipped_flipped.jpg: GT=1, Pred=0
# 5_flipped_flipped_flipped.jpg: GT=1, Pred=3
# 6.png: GT=1, Pred=0
# 60.png: GT=1, Pred=0
# 60_flipped.jpg: GT=1, Pred=0
# 60_flipped_flipped.jpg: GT=1, Pred=0
# 60_flipped_flipped_flipped.jpg: GT=1, Pred=0
# 61.png: GT=1, Pred=2
# 61_flipped_flipped.jpg: GT=1, Pred=3
# 62.png: GT=1, Pred=3
# 62_flipped.jpg: GT=1, Pred=0
# 62_flipped_flipped.jpg: GT=1, Pred=2
# 62_flipped_flipped_flipped.jpg: GT=1, Pred=0
# 63.png: GT=1, Pred=2
# 63_flipped.jpg: GT=1, Pred=0
# 63_flipped_flipped_flipped.jpg: GT=1, Pred=0
# 64_flipped.jpg: GT=1, Pred=0
# 64_flipped_flipped_flipped.jpg: GT=1, Pred=0
# 65.png: GT=1, Pred=0
# 65_flipped.jpg: GT=1, Pred=0
# 65_flipped_flipped.jpg: GT=1, Pred=0
# 65_flipped_flipped_flipped.jpg: GT=1, Pred=0
# 66.png: GT=1, Pred=0
# 66_flipped.jpg: GT=1, Pred=0
# 66_flipped_flipped.jpg: GT=1, Pred=0
# 66_flipped_flipped_flipped.jpg: GT=1, Pred=0
# 67.png: GT=1, Pred=0
# 68.png: GT=1, Pred=2
# 68_flipped.jpg: GT=1, Pred=0
# 68_flipped_flipped.jpg: GT=1, Pred=2
# 68_flipped_flipped_flipped.jpg: GT=1, Pred=0
# 69_flipped.jpg: GT=1, Pred=2
# 69_flipped_flipped.jpg: GT=1, Pred=2
# 69_flipped_flipped_flipped.jpg: GT=1, Pred=2
# 6_flipped.jpg: GT=1, Pred=2
# 6_flipped_flipped.jpg: GT=1, Pred=0
# 6_flipped_flipped_flipped.jpg: GT=1, Pred=2
# 7.png: GT=1, Pred=0
# 70.png: GT=1, Pred=2
# 70_flipped_flipped.jpg: GT=1, Pred=3
# 71.png: GT=1, Pred=2
# 71_flipped.jpg: GT=1, Pred=2
# 71_flipped_flipped.jpg: GT=1, Pred=2
# 71_flipped_flipped_flipped.jpg: GT=1, Pred=2
# 72.png: GT=1, Pred=2
# 72_flipped.jpg: GT=1, Pred=3
# 72_flipped_flipped.jpg: GT=1, Pred=2
# 72_flipped_flipped_flipped.jpg: GT=1, Pred=3
# 73.png: GT=1, Pred=3
# 73_flipped_flipped.jpg: GT=1, Pred=3
# 74.png: GT=1, Pred=3
# 74_flipped.jpg: GT=1, Pred=2
# 74_flipped_flipped.jpg: GT=1, Pred=3
# 74_flipped_flipped_flipped.jpg: GT=1, Pred=2
# 75.png: GT=1, Pred=3
# 75_flipped.jpg: GT=1, Pred=2
# 75_flipped_flipped_flipped.jpg: GT=1, Pred=2
# 76.png: GT=1, Pred=2
# 76_flipped.jpg: GT=1, Pred=2
# 76_flipped_flipped.jpg: GT=1, Pred=2
# 76_flipped_flipped_flipped.jpg: GT=1, Pred=2
# 77.png: GT=1, Pred=2
# 77_flipped_flipped.jpg: GT=1, Pred=2
# 79.png: GT=1, Pred=2
# 79_flipped.jpg: GT=1, Pred=3
# 79_flipped_flipped.jpg: GT=1, Pred=2
# 79_flipped_flipped_flipped.jpg: GT=1, Pred=3
# 7_flipped.jpg: GT=1, Pred=2
# 7_flipped_flipped.jpg: GT=1, Pred=0
# 7_flipped_flipped_flipped.jpg: GT=1, Pred=2
# 8.png: GT=1, Pred=0
# 80.png: GT=1, Pred=2
# 80_flipped.jpg: GT=1, Pred=2
# 80_flipped_flipped.jpg: GT=1, Pred=2
# 80_flipped_flipped_flipped.jpg: GT=1, Pred=2
# 81.png: GT=1, Pred=2
# 81_flipped_flipped.jpg: GT=1, Pred=2
# 82.png: GT=1, Pred=2
# 82_flipped.jpg: GT=1, Pred=2
# 82_flipped_flipped.jpg: GT=1, Pred=2
# 82_flipped_flipped_flipped.jpg: GT=1, Pred=2
# 83.png: GT=1, Pred=2
# 83_flipped_flipped.jpg: GT=1, Pred=2
# 84.png: GT=1, Pred=2
# 84_flipped_flipped.jpg: GT=1, Pred=2
# 85.png: GT=1, Pred=0
# 85_flipped_flipped.jpg: GT=1, Pred=0
# 87.png: GT=1, Pred=3
# 87_flipped_flipped.jpg: GT=1, Pred=3
# 88.png: GT=1, Pred=0
# 88_flipped.jpg: GT=1, Pred=3
# 88_flipped_flipped_flipped.jpg: GT=1, Pred=2
# 89.png: GT=1, Pred=0
# 89_flipped.jpg: GT=1, Pred=0
# 89_flipped_flipped.jpg: GT=1, Pred=0
# 89_flipped_flipped_flipped.jpg: GT=1, Pred=0
# 8_flipped_flipped.jpg: GT=1, Pred=0
# 9.png: GT=1, Pred=0
# 90_flipped.jpg: GT=1, Pred=0
# 90_flipped_flipped_flipped.jpg: GT=1, Pred=0
# 91_flipped.jpg: GT=1, Pred=2
# 91_flipped_flipped_flipped.jpg: GT=1, Pred=2
# 92.png: GT=1, Pred=3
# 92_flipped.jpg: GT=1, Pred=4
# 92_flipped_flipped.jpg: GT=1, Pred=3
# 92_flipped_flipped_flipped.jpg: GT=1, Pred=4
# 93.png: GT=1, Pred=2
# 93_flipped.jpg: GT=1, Pred=2
# 93_flipped_flipped.jpg: GT=1, Pred=2
# 93_flipped_flipped_flipped.jpg: GT=1, Pred=2
# 94.png: GT=1, Pred=2
# 94_flipped.jpg: GT=1, Pred=2
# 94_flipped_flipped.jpg: GT=1, Pred=2
# 94_flipped_flipped_flipped.jpg: GT=1, Pred=2
# 95.png: GT=1, Pred=2
# 95_flipped.jpg: GT=1, Pred=2
# 95_flipped_flipped_flipped.jpg: GT=1, Pred=2
# 96.png: GT=1, Pred=0
# 96_flipped.jpg: GT=1, Pred=0
# 96_flipped_flipped_flipped.jpg: GT=1, Pred=0
# 97.png: GT=1, Pred=0
# 98.png: GT=1, Pred=3
# 98_flipped.jpg: GT=1, Pred=2
# 98_flipped_flipped.jpg: GT=1, Pred=5
# 98_flipped_flipped_flipped.jpg: GT=1, Pred=2
# 99.png: GT=1, Pred=0
# 99_flipped.jpg: GT=1, Pred=0
# 99_flipped_flipped.jpg: GT=1, Pred=0
# 99_flipped_flipped_flipped.jpg: GT=1, Pred=0
# 9_flipped.jpg: GT=1, Pred=3
# 9_flipped_flipped.jpg: GT=1, Pred=0
# 9_flipped_flipped_flipped.jpg: GT=1, Pred=3
# 10- (1).png: GT=10, Pred=1
# 10- (1)_flipped.jpg: GT=10, Pred=1
# 10- (1)_flipped_flipped.jpg: GT=10, Pred=1
# 10- (1)_flipped_flipped_flipped.jpg: GT=10, Pred=1
# 10- (10).png: GT=10, Pred=0
# 10- (10)_flipped.jpg: GT=10, Pred=1
# 10- (10)_flipped_flipped.jpg: GT=10, Pred=1
# 10- (10)_flipped_flipped_flipped.jpg: GT=10, Pred=1
# 10- (11).png: GT=10, Pred=1
# 10- (11)_flipped.jpg: GT=10, Pred=1
# 10- (11)_flipped_flipped.jpg: GT=10, Pred=1
# 10- (11)_flipped_flipped_flipped.jpg: GT=10, Pred=1
# 10- (12).png: GT=10, Pred=1
# 10- (12)_flipped.jpg: GT=10, Pred=1
# 10- (12)_flipped_flipped.jpg: GT=10, Pred=1
# 10- (12)_flipped_flipped_flipped.jpg: GT=10, Pred=1
# 10- (13).png: GT=10, Pred=1
# 10- (13)_flipped.jpg: GT=10, Pred=1
# 10- (13)_flipped_flipped.jpg: GT=10, Pred=1
# 10- (13)_flipped_flipped_flipped.jpg: GT=10, Pred=1
# 10- (14).png: GT=10, Pred=1
# 10- (14)_flipped.jpg: GT=10, Pred=1
# 10- (14)_flipped_flipped.jpg: GT=10, Pred=1
# 10- (14)_flipped_flipped_flipped.jpg: GT=10, Pred=1
# 10- (15).png: GT=10, Pred=1
# 10- (15)_flipped.jpg: GT=10, Pred=1
# 10- (15)_flipped_flipped.jpg: GT=10, Pred=1
# 10- (15)_flipped_flipped_flipped.jpg: GT=10, Pred=1
# 10- (16).png: GT=10, Pred=0
# 10- (16)_flipped.jpg: GT=10, Pred=0
# 10- (16)_flipped_flipped.jpg: GT=10, Pred=1
# 10- (16)_flipped_flipped_flipped.jpg: GT=10, Pred=0
# 10- (17).png: GT=10, Pred=1
# 10- (17)_flipped.jpg: GT=10, Pred=1
# 10- (17)_flipped_flipped.jpg: GT=10, Pred=1
# 10- (17)_flipped_flipped_flipped.jpg: GT=10, Pred=1
# 10- (18).png: GT=10, Pred=1
# 10- (18)_flipped.jpg: GT=10, Pred=1
# 10- (18)_flipped_flipped.jpg: GT=10, Pred=1
# 10- (18)_flipped_flipped_flipped.jpg: GT=10, Pred=1
# 10- (19).png: GT=10, Pred=1
# 10- (19)_flipped.jpg: GT=10, Pred=1
# 10- (19)_flipped_flipped.jpg: GT=10, Pred=1
# 10- (19)_flipped_flipped_flipped.jpg: GT=10, Pred=1
# 10- (2).png: GT=10, Pred=1
# 10- (2)_flipped.jpg: GT=10, Pred=1
# 10- (2)_flipped_flipped.jpg: GT=10, Pred=1
# 10- (2)_flipped_flipped_flipped.jpg: GT=10, Pred=1
# 10- (20).png: GT=10, Pred=1
# 10- (20)_flipped.jpg: GT=10, Pred=1
# 10- (20)_flipped_flipped.jpg: GT=10, Pred=1
# 10- (20)_flipped_flipped_flipped.jpg: GT=10, Pred=1
# 10- (21).png: GT=10, Pred=0
# 10- (21)_flipped.jpg: GT=10, Pred=2
# 10- (21)_flipped_flipped.jpg: GT=10, Pred=2
# 10- (21)_flipped_flipped_flipped.jpg: GT=10, Pred=2
# 10- (22).png: GT=10, Pred=0
# 10- (22)_flipped.jpg: GT=10, Pred=1
# 10- (22)_flipped_flipped.jpg: GT=10, Pred=2
# 10- (22)_flipped_flipped_flipped.jpg: GT=10, Pred=1
# 10- (23).png: GT=10, Pred=2
# 10- (23)_flipped.jpg: GT=10, Pred=2
# 10- (23)_flipped_flipped.jpg: GT=10, Pred=4
# 10- (23)_flipped_flipped_flipped.jpg: GT=10, Pred=2
# 10- (24).png: GT=10, Pred=2
# 10- (24)_flipped.jpg: GT=10, Pred=4
# 10- (24)_flipped_flipped.jpg: GT=10, Pred=4
# 10- (24)_flipped_flipped_flipped.jpg: GT=10, Pred=4
# 10- (25).png: GT=10, Pred=3
# 10- (25)_flipped.jpg: GT=10, Pred=2
# 10- (25)_flipped_flipped.jpg: GT=10, Pred=3
# 10- (25)_flipped_flipped_flipped.jpg: GT=10, Pred=2
# 10- (26).png: GT=10, Pred=5
# 10- (26)_flipped.jpg: GT=10, Pred=3
# 10- (26)_flipped_flipped.jpg: GT=10, Pred=5
# 10- (26)_flipped_flipped_flipped.jpg: GT=10, Pred=3
# 10- (27).png: GT=10, Pred=3
# 10- (27)_flipped.jpg: GT=10, Pred=2
# 10- (27)_flipped_flipped.jpg: GT=10, Pred=4
# 10- (27)_flipped_flipped_flipped.jpg: GT=10, Pred=2
# 10- (28).png: GT=10, Pred=3
# 10- (28)_flipped.jpg: GT=10, Pred=2
# 10- (28)_flipped_flipped.jpg: GT=10, Pred=4
# 10- (28)_flipped_flipped_flipped.jpg: GT=10, Pred=2
# 10- (29).png: GT=10, Pred=3
# 10- (29)_flipped.jpg: GT=10, Pred=3
# 10- (29)_flipped_flipped.jpg: GT=10, Pred=4
# 10- (29)_flipped_flipped_flipped.jpg: GT=10, Pred=3
# 10- (3).png: GT=10, Pred=1
# 10- (3)_flipped.jpg: GT=10, Pred=0
# 10- (3)_flipped_flipped.jpg: GT=10, Pred=1
# 10- (3)_flipped_flipped_flipped.jpg: GT=10, Pred=0
# 10- (30).png: GT=10, Pred=3
# 10- (30)_flipped.jpg: GT=10, Pred=3
# 10- (30)_flipped_flipped.jpg: GT=10, Pred=5
# 10- (30)_flipped_flipped_flipped.jpg: GT=10, Pred=3
# 10- (31).png: GT=10, Pred=2
# 10- (31)_flipped.jpg: GT=10, Pred=2
# 10- (31)_flipped_flipped.jpg: GT=10, Pred=4
# 10- (31)_flipped_flipped_flipped.jpg: GT=10, Pred=2
# 10- (32).png: GT=10, Pred=0
# 10- (32)_flipped.jpg: GT=10, Pred=1
# 10- (32)_flipped_flipped.jpg: GT=10, Pred=2
# 10- (32)_flipped_flipped_flipped.jpg: GT=10, Pred=1
# 10- (33).png: GT=10, Pred=2
# 10- (33)_flipped.jpg: GT=10, Pred=4
# 10- (33)_flipped_flipped.jpg: GT=10, Pred=3
# 10- (33)_flipped_flipped_flipped.jpg: GT=10, Pred=4
# 10- (34).png: GT=10, Pred=0
# 10- (34)_flipped.jpg: GT=10, Pred=2
# 10- (34)_flipped_flipped.jpg: GT=10, Pred=2
# 10- (34)_flipped_flipped_flipped.jpg: GT=10, Pred=2
# 10- (35).png: GT=10, Pred=0
# 10- (35)_flipped.jpg: GT=10, Pred=0
# 10- (35)_flipped_flipped.jpg: GT=10, Pred=2
# 10- (35)_flipped_flipped_flipped.jpg: GT=10, Pred=0
# 10- (36).png: GT=10, Pred=1
# 10- (36)_flipped.jpg: GT=10, Pred=2
# 10- (36)_flipped_flipped.jpg: GT=10, Pred=3
# 10- (36)_flipped_flipped_flipped.jpg: GT=10, Pred=2
# 10- (37).png: GT=10, Pred=1
# 10- (37)_flipped.jpg: GT=10, Pred=1
# 10- (37)_flipped_flipped.jpg: GT=10, Pred=2
# 10- (37)_flipped_flipped_flipped.jpg: GT=10, Pred=1
# 10- (38).png: GT=10, Pred=1
# 10- (38)_flipped.jpg: GT=10, Pred=2
# 10- (38)_flipped_flipped.jpg: GT=10, Pred=3
# 10- (38)_flipped_flipped_flipped.jpg: GT=10, Pred=2
# 10- (39).png: GT=10, Pred=0
# 10- (39)_flipped.jpg: GT=10, Pred=1
# 10- (39)_flipped_flipped.jpg: GT=10, Pred=2
# 10- (39)_flipped_flipped_flipped.jpg: GT=10, Pred=1
# 10- (4).png: GT=10, Pred=1
# 10- (4)_flipped.jpg: GT=10, Pred=2
# 10- (4)_flipped_flipped.jpg: GT=10, Pred=1
# 10- (4)_flipped_flipped_flipped.jpg: GT=10, Pred=2
# 10- (40).png: GT=10, Pred=1
# 10- (40)_flipped.jpg: GT=10, Pred=2
# 10- (40)_flipped_flipped.jpg: GT=10, Pred=5
# 10- (40)_flipped_flipped_flipped.jpg: GT=10, Pred=2
# 10- (41).png: GT=10, Pred=2
# 10- (41)_flipped.jpg: GT=10, Pred=0
# 10- (41)_flipped_flipped.jpg: GT=10, Pred=1
# 10- (41)_flipped_flipped_flipped.jpg: GT=10, Pred=0
# 10- (42).png: GT=10, Pred=0
# 10- (42)_flipped.jpg: GT=10, Pred=3
# 10- (42)_flipped_flipped.jpg: GT=10, Pred=4
# 10- (42)_flipped_flipped_flipped.jpg: GT=10, Pred=3
# 10- (43).png: GT=10, Pred=0
# 10- (43)_flipped.jpg: GT=10, Pred=1
# 10- (43)_flipped_flipped.jpg: GT=10, Pred=2
# 10- (43)_flipped_flipped_flipped.jpg: GT=10, Pred=1
# 10- (44).png: GT=10, Pred=0
# 10- (44)_flipped.jpg: GT=10, Pred=2
# 10- (44)_flipped_flipped.jpg: GT=10, Pred=4
# 10- (44)_flipped_flipped_flipped.jpg: GT=10, Pred=2
# 10- (45).png: GT=10, Pred=2
# 10- (45)_flipped.jpg: GT=10, Pred=1
# 10- (45)_flipped_flipped.jpg: GT=10, Pred=0
# 10- (45)_flipped_flipped_flipped.jpg: GT=10, Pred=1
# 10- (46).png: GT=10, Pred=1
# 10- (46)_flipped.jpg: GT=10, Pred=1
# 10- (46)_flipped_flipped.jpg: GT=10, Pred=3
# 10- (46)_flipped_flipped_flipped.jpg: GT=10, Pred=1
# 10- (47).png: GT=10, Pred=1
# 10- (47)_flipped.jpg: GT=10, Pred=3
# 10- (47)_flipped_flipped.jpg: GT=10, Pred=4
# 10- (47)_flipped_flipped_flipped.jpg: GT=10, Pred=3
# 10- (48).png: GT=10, Pred=3
# 10- (48)_flipped.jpg: GT=10, Pred=2
# 10- (48)_flipped_flipped.jpg: GT=10, Pred=2
# 10- (48)_flipped_flipped_flipped.jpg: GT=10, Pred=2
# 10- (49).png: GT=10, Pred=2
# 10- (49)_flipped.jpg: GT=10, Pred=1
# 10- (49)_flipped_flipped.jpg: GT=10, Pred=4
# 10- (49)_flipped_flipped_flipped.jpg: GT=10, Pred=1
# 10- (5).png: GT=10, Pred=1
# 10- (5)_flipped.jpg: GT=10, Pred=1
# 10- (5)_flipped_flipped.jpg: GT=10, Pred=1
# 10- (5)_flipped_flipped_flipped.jpg: GT=10, Pred=1
# 10- (50).png: GT=10, Pred=2
# 10- (50)_flipped.jpg: GT=10, Pred=1
# 10- (50)_flipped_flipped.jpg: GT=10, Pred=2
# 10- (50)_flipped_flipped_flipped.jpg: GT=10, Pred=1
# 10- (51).png: GT=10, Pred=1
# 10- (51)_flipped.jpg: GT=10, Pred=2
# 10- (51)_flipped_flipped.jpg: GT=10, Pred=4
# 10- (51)_flipped_flipped_flipped.jpg: GT=10, Pred=2
# 10- (52).png: GT=10, Pred=1
# 10- (52)_flipped.jpg: GT=10, Pred=1
# 10- (52)_flipped_flipped.jpg: GT=10, Pred=1
# 10- (52)_flipped_flipped_flipped.jpg: GT=10, Pred=1
# 10- (6).png: GT=10, Pred=1
# 10- (6)_flipped.jpg: GT=10, Pred=1
# 10- (6)_flipped_flipped.jpg: GT=10, Pred=1
# 10- (6)_flipped_flipped_flipped.jpg: GT=10, Pred=1
# 10- (7).png: GT=10, Pred=1
# 10- (7)_flipped.jpg: GT=10, Pred=2
# 10- (7)_flipped_flipped.jpg: GT=10, Pred=1
# 10- (7)_flipped_flipped_flipped.jpg: GT=10, Pred=2
# 10- (8).png: GT=10, Pred=0
# 10- (8)_flipped.jpg: GT=10, Pred=0
# 10- (8)_flipped_flipped.jpg: GT=10, Pred=1
# 10- (8)_flipped_flipped_flipped.jpg: GT=10, Pred=0
# 10- (9).png: GT=10, Pred=1
# 10- (9)_flipped.jpg: GT=10, Pred=1
# 10- (9)_flipped_flipped.jpg: GT=10, Pred=1
# 10- (9)_flipped_flipped_flipped.jpg: GT=10, Pred=1
# 11- (1).png: GT=11, Pred=2
# 11- (1)_flipped.jpg: GT=11, Pred=0
# 11- (1)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (1)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (10).png: GT=11, Pred=2
# 11- (10)_flipped.jpg: GT=11, Pred=0
# 11- (10)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (10)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (11).png: GT=11, Pred=0
# 11- (11)_flipped.jpg: GT=11, Pred=1
# 11- (11)_flipped_flipped.jpg: GT=11, Pred=1
# 11- (11)_flipped_flipped_flipped.jpg: GT=11, Pred=1
# 11- (12).png: GT=11, Pred=1
# 11- (12)_flipped.jpg: GT=11, Pred=1
# 11- (12)_flipped_flipped.jpg: GT=11, Pred=1
# 11- (12)_flipped_flipped_flipped.jpg: GT=11, Pred=1
# 11- (13).png: GT=11, Pred=0
# 11- (13)_flipped.jpg: GT=11, Pred=1
# 11- (13)_flipped_flipped.jpg: GT=11, Pred=2
# 11- (13)_flipped_flipped_flipped.jpg: GT=11, Pred=1
# 11- (14).png: GT=11, Pred=3
# 11- (14)_flipped.jpg: GT=11, Pred=0
# 11- (14)_flipped_flipped.jpg: GT=11, Pred=2
# 11- (14)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (15).png: GT=11, Pred=0
# 11- (15)_flipped.jpg: GT=11, Pred=1
# 11- (15)_flipped_flipped.jpg: GT=11, Pred=1
# 11- (15)_flipped_flipped_flipped.jpg: GT=11, Pred=1
# 11- (16).png: GT=11, Pred=0
# 11- (16)_flipped.jpg: GT=11, Pred=1
# 11- (16)_flipped_flipped.jpg: GT=11, Pred=1
# 11- (16)_flipped_flipped_flipped.jpg: GT=11, Pred=1
# 11- (17).png: GT=11, Pred=0
# 11- (17)_flipped.jpg: GT=11, Pred=1
# 11- (17)_flipped_flipped.jpg: GT=11, Pred=2
# 11- (17)_flipped_flipped_flipped.jpg: GT=11, Pred=1
# 11- (18).png: GT=11, Pred=0
# 11- (18)_flipped.jpg: GT=11, Pred=1
# 11- (18)_flipped_flipped.jpg: GT=11, Pred=1
# 11- (18)_flipped_flipped_flipped.jpg: GT=11, Pred=1
# 11- (19).png: GT=11, Pred=0
# 11- (19)_flipped.jpg: GT=11, Pred=0
# 11- (19)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (19)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (2).png: GT=11, Pred=0
# 11- (2)_flipped.jpg: GT=11, Pred=0
# 11- (2)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (2)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (20).png: GT=11, Pred=0
# 11- (20)_flipped.jpg: GT=11, Pred=0
# 11- (20)_flipped_flipped.jpg: GT=11, Pred=2
# 11- (20)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (21).png: GT=11, Pred=0
# 11- (21)_flipped.jpg: GT=11, Pred=1
# 11- (21)_flipped_flipped.jpg: GT=11, Pred=1
# 11- (21)_flipped_flipped_flipped.jpg: GT=11, Pred=1
# 11- (22).png: GT=11, Pred=0
# 11- (22)_flipped.jpg: GT=11, Pred=0
# 11- (22)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (22)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (23).png: GT=11, Pred=0
# 11- (23)_flipped.jpg: GT=11, Pred=1
# 11- (23)_flipped_flipped.jpg: GT=11, Pred=2
# 11- (23)_flipped_flipped_flipped.jpg: GT=11, Pred=1
# 11- (24).png: GT=11, Pred=1
# 11- (24)_flipped.jpg: GT=11, Pred=0
# 11- (24)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (24)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (25).png: GT=11, Pred=0
# 11- (25)_flipped.jpg: GT=11, Pred=1
# 11- (25)_flipped_flipped.jpg: GT=11, Pred=1
# 11- (25)_flipped_flipped_flipped.jpg: GT=11, Pred=1
# 11- (26).png: GT=11, Pred=0
# 11- (26)_flipped.jpg: GT=11, Pred=1
# 11- (26)_flipped_flipped.jpg: GT=11, Pred=1
# 11- (26)_flipped_flipped_flipped.jpg: GT=11, Pred=1
# 11- (27).png: GT=11, Pred=0
# 11- (27)_flipped.jpg: GT=11, Pred=1
# 11- (27)_flipped_flipped.jpg: GT=11, Pred=2
# 11- (27)_flipped_flipped_flipped.jpg: GT=11, Pred=1
# 11- (28).png: GT=11, Pred=1
# 11- (28)_flipped.jpg: GT=11, Pred=1
# 11- (28)_flipped_flipped.jpg: GT=11, Pred=2
# 11- (28)_flipped_flipped_flipped.jpg: GT=11, Pred=1
# 11- (29).png: GT=11, Pred=0
# 11- (29)_flipped.jpg: GT=11, Pred=2
# 11- (29)_flipped_flipped.jpg: GT=11, Pred=2
# 11- (29)_flipped_flipped_flipped.jpg: GT=11, Pred=2
# 11- (3).png: GT=11, Pred=0
# 11- (3)_flipped.jpg: GT=11, Pred=1
# 11- (3)_flipped_flipped.jpg: GT=11, Pred=1
# 11- (3)_flipped_flipped_flipped.jpg: GT=11, Pred=1
# 11- (30).png: GT=11, Pred=0
# 11- (30)_flipped.jpg: GT=11, Pred=2
# 11- (30)_flipped_flipped.jpg: GT=11, Pred=1
# 11- (30)_flipped_flipped_flipped.jpg: GT=11, Pred=2
# 11- (31).png: GT=11, Pred=1
# 11- (31)_flipped.jpg: GT=11, Pred=1
# 11- (31)_flipped_flipped.jpg: GT=11, Pred=1
# 11- (31)_flipped_flipped_flipped.jpg: GT=11, Pred=1
# 11- (32).png: GT=11, Pred=0
# 11- (32)_flipped.jpg: GT=11, Pred=2
# 11- (32)_flipped_flipped.jpg: GT=11, Pred=1
# 11- (32)_flipped_flipped_flipped.jpg: GT=11, Pred=2
# 11- (33).png: GT=11, Pred=0
# 11- (33)_flipped.jpg: GT=11, Pred=0
# 11- (33)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (33)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (34).png: GT=11, Pred=1
# 11- (34)_flipped.jpg: GT=11, Pred=0
# 11- (34)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (34)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (35).png: GT=11, Pred=0
# 11- (35)_flipped.jpg: GT=11, Pred=1
# 11- (35)_flipped_flipped.jpg: GT=11, Pred=2
# 11- (35)_flipped_flipped_flipped.jpg: GT=11, Pred=1
# 11- (36).png: GT=11, Pred=0
# 11- (36)_flipped.jpg: GT=11, Pred=1
# 11- (36)_flipped_flipped.jpg: GT=11, Pred=1
# 11- (36)_flipped_flipped_flipped.jpg: GT=11, Pred=1
# 11- (37).png: GT=11, Pred=0
# 11- (37)_flipped.jpg: GT=11, Pred=1
# 11- (37)_flipped_flipped.jpg: GT=11, Pred=1
# 11- (37)_flipped_flipped_flipped.jpg: GT=11, Pred=1
# 11- (38).png: GT=11, Pred=0
# 11- (38)_flipped.jpg: GT=11, Pred=1
# 11- (38)_flipped_flipped.jpg: GT=11, Pred=2
# 11- (38)_flipped_flipped_flipped.jpg: GT=11, Pred=1
# 11- (39).png: GT=11, Pred=1
# 11- (39)_flipped.jpg: GT=11, Pred=1
# 11- (39)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (39)_flipped_flipped_flipped.jpg: GT=11, Pred=1
# 11- (4).png: GT=11, Pred=0
# 11- (4)_flipped.jpg: GT=11, Pred=2
# 11- (4)_flipped_flipped.jpg: GT=11, Pred=2
# 11- (4)_flipped_flipped_flipped.jpg: GT=11, Pred=2
# 11- (40).png: GT=11, Pred=0
# 11- (40)_flipped.jpg: GT=11, Pred=1
# 11- (40)_flipped_flipped.jpg: GT=11, Pred=1
# 11- (40)_flipped_flipped_flipped.jpg: GT=11, Pred=1
# 11- (41).png: GT=11, Pred=2
# 11- (41)_flipped.jpg: GT=11, Pred=2
# 11- (41)_flipped_flipped.jpg: GT=11, Pred=2
# 11- (41)_flipped_flipped_flipped.jpg: GT=11, Pred=2
# 11- (42).png: GT=11, Pred=0
# 11- (42)_flipped.jpg: GT=11, Pred=1
# 11- (42)_flipped_flipped.jpg: GT=11, Pred=2
# 11- (42)_flipped_flipped_flipped.jpg: GT=11, Pred=1
# 11- (43).png: GT=11, Pred=0
# 11- (43)_flipped.jpg: GT=11, Pred=2
# 11- (43)_flipped_flipped.jpg: GT=11, Pred=2
# 11- (43)_flipped_flipped_flipped.jpg: GT=11, Pred=2
# 11- (44).png: GT=11, Pred=0
# 11- (44)_flipped.jpg: GT=11, Pred=2
# 11- (44)_flipped_flipped.jpg: GT=11, Pred=2
# 11- (44)_flipped_flipped_flipped.jpg: GT=11, Pred=2
# 11- (45).png: GT=11, Pred=0
# 11- (45)_flipped.jpg: GT=11, Pred=0
# 11- (45)_flipped_flipped.jpg: GT=11, Pred=1
# 11- (45)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (46).png: GT=11, Pred=1
# 11- (46)_flipped.jpg: GT=11, Pred=1
# 11- (46)_flipped_flipped.jpg: GT=11, Pred=1
# 11- (46)_flipped_flipped_flipped.jpg: GT=11, Pred=1
# 11- (47).png: GT=11, Pred=0
# 11- (47)_flipped.jpg: GT=11, Pred=1
# 11- (47)_flipped_flipped.jpg: GT=11, Pred=1
# 11- (47)_flipped_flipped_flipped.jpg: GT=11, Pred=1
# 11- (48).png: GT=11, Pred=0
# 11- (48)_flipped.jpg: GT=11, Pred=0
# 11- (48)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (48)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (49).png: GT=11, Pred=0
# 11- (49)_flipped.jpg: GT=11, Pred=0
# 11- (49)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (49)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (5).png: GT=11, Pred=0
# 11- (5)_flipped.jpg: GT=11, Pred=1
# 11- (5)_flipped_flipped.jpg: GT=11, Pred=2
# 11- (5)_flipped_flipped_flipped.jpg: GT=11, Pred=1
# 11- (50).png: GT=11, Pred=0
# 11- (50)_flipped.jpg: GT=11, Pred=2
# 11- (50)_flipped_flipped.jpg: GT=11, Pred=1
# 11- (50)_flipped_flipped_flipped.jpg: GT=11, Pred=2
# 11- (51).png: GT=11, Pred=0
# 11- (51)_flipped.jpg: GT=11, Pred=0
# 11- (51)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (51)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (52).png: GT=11, Pred=0
# 11- (52)_flipped.jpg: GT=11, Pred=0
# 11- (52)_flipped_flipped.jpg: GT=11, Pred=1
# 11- (52)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (53).png: GT=11, Pred=1
# 11- (53)_flipped.jpg: GT=11, Pred=0
# 11- (53)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (53)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (54).png: GT=11, Pred=1
# 11- (54)_flipped.jpg: GT=11, Pred=0
# 11- (54)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (54)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (55).png: GT=11, Pred=0
# 11- (55)_flipped.jpg: GT=11, Pred=1
# 11- (55)_flipped_flipped.jpg: GT=11, Pred=1
# 11- (55)_flipped_flipped_flipped.jpg: GT=11, Pred=1
# 11- (56).png: GT=11, Pred=1
# 11- (56)_flipped.jpg: GT=11, Pred=1
# 11- (56)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (56)_flipped_flipped_flipped.jpg: GT=11, Pred=1
# 11- (57).png: GT=11, Pred=0
# 11- (57)_flipped.jpg: GT=11, Pred=0
# 11- (57)_flipped_flipped.jpg: GT=11, Pred=1
# 11- (57)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (58).png: GT=11, Pred=2
# 11- (58)_flipped.jpg: GT=11, Pred=0
# 11- (58)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (58)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (59).png: GT=11, Pred=0
# 11- (59)_flipped.jpg: GT=11, Pred=0
# 11- (59)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (59)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (6).png: GT=11, Pred=0
# 11- (6)_flipped.jpg: GT=11, Pred=1
# 11- (6)_flipped_flipped.jpg: GT=11, Pred=1
# 11- (6)_flipped_flipped_flipped.jpg: GT=11, Pred=1
# 11- (60).png: GT=11, Pred=0
# 11- (60)_flipped.jpg: GT=11, Pred=1
# 11- (60)_flipped_flipped.jpg: GT=11, Pred=2
# 11- (60)_flipped_flipped_flipped.jpg: GT=11, Pred=1
# 11- (61).png: GT=11, Pred=0
# 11- (61)_flipped.jpg: GT=11, Pred=0
# 11- (61)_flipped_flipped.jpg: GT=11, Pred=1
# 11- (61)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (62).png: GT=11, Pred=2
# 11- (62)_flipped.jpg: GT=11, Pred=0
# 11- (62)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (62)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (63).png: GT=11, Pred=0
# 11- (63)_flipped.jpg: GT=11, Pred=0
# 11- (63)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (63)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (64).png: GT=11, Pred=2
# 11- (64)_flipped.jpg: GT=11, Pred=1
# 11- (64)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (64)_flipped_flipped_flipped.jpg: GT=11, Pred=1
# 11- (65).png: GT=11, Pred=0
# 11- (65)_flipped.jpg: GT=11, Pred=0
# 11- (65)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (65)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (66).png: GT=11, Pred=1
# 11- (66)_flipped.jpg: GT=11, Pred=1
# 11- (66)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (66)_flipped_flipped_flipped.jpg: GT=11, Pred=1
# 11- (67).png: GT=11, Pred=0
# 11- (67)_flipped.jpg: GT=11, Pred=0
# 11- (67)_flipped_flipped.jpg: GT=11, Pred=1
# 11- (67)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (68).png: GT=11, Pred=3
# 11- (68)_flipped.jpg: GT=11, Pred=1
# 11- (68)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (68)_flipped_flipped_flipped.jpg: GT=11, Pred=1
# 11- (69).png: GT=11, Pred=0
# 11- (69)_flipped.jpg: GT=11, Pred=0
# 11- (69)_flipped_flipped.jpg: GT=11, Pred=1
# 11- (69)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (7).png: GT=11, Pred=0
# 11- (7)_flipped.jpg: GT=11, Pred=3
# 11- (7)_flipped_flipped.jpg: GT=11, Pred=3
# 11- (7)_flipped_flipped_flipped.jpg: GT=11, Pred=3
# 11- (70).png: GT=11, Pred=1
# 11- (70)_flipped.jpg: GT=11, Pred=0
# 11- (70)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (70)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (71).png: GT=11, Pred=0
# 11- (71)_flipped.jpg: GT=11, Pred=0
# 11- (71)_flipped_flipped.jpg: GT=11, Pred=1
# 11- (71)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (72).png: GT=11, Pred=2
# 11- (72)_flipped.jpg: GT=11, Pred=1
# 11- (72)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (72)_flipped_flipped_flipped.jpg: GT=11, Pred=1
# 11- (8).png: GT=11, Pred=0
# 11- (8)_flipped.jpg: GT=11, Pred=1
# 11- (8)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (8)_flipped_flipped_flipped.jpg: GT=11, Pred=1
# 11- (9).png: GT=11, Pred=0
# 11- (9)_flipped.jpg: GT=11, Pred=1
# 11- (9)_flipped_flipped.jpg: GT=11, Pred=1
# 11- (9)_flipped_flipped_flipped.jpg: GT=11, Pred=1
# 12- (1).png: GT=12, Pred=3
# 12- (1)_flipped.jpg: GT=12, Pred=2
# 12- (1)_flipped_flipped.jpg: GT=12, Pred=2
# 12- (1)_flipped_flipped_flipped.jpg: GT=12, Pred=2
# 12- (10).png: GT=12, Pred=0
# 12- (10)_flipped.jpg: GT=12, Pred=2
# 12- (10)_flipped_flipped.jpg: GT=12, Pred=2
# 12- (10)_flipped_flipped_flipped.jpg: GT=12, Pred=2
# 12- (11).png: GT=12, Pred=2
# 12- (11)_flipped.jpg: GT=12, Pred=2
# 12- (11)_flipped_flipped.jpg: GT=12, Pred=3
# 12- (11)_flipped_flipped_flipped.jpg: GT=12, Pred=2
# 12- (12).png: GT=12, Pred=3
# 12- (12)_flipped.jpg: GT=12, Pred=2
# 12- (12)_flipped_flipped.jpg: GT=12, Pred=3
# 12- (12)_flipped_flipped_flipped.jpg: GT=12, Pred=2
# 12- (13).png: GT=12, Pred=0
# 12- (13)_flipped.jpg: GT=12, Pred=2
# 12- (13)_flipped_flipped.jpg: GT=12, Pred=3
# 12- (13)_flipped_flipped_flipped.jpg: GT=12, Pred=2
# 12- (14).png: GT=12, Pred=1
# 12- (14)_flipped.jpg: GT=12, Pred=3
# 12- (14)_flipped_flipped.jpg: GT=12, Pred=4
# 12- (14)_flipped_flipped_flipped.jpg: GT=12, Pred=3
# 12- (15).png: GT=12, Pred=2
# 12- (15)_flipped.jpg: GT=12, Pred=2
# 12- (15)_flipped_flipped.jpg: GT=12, Pred=3
# 12- (15)_flipped_flipped_flipped.jpg: GT=12, Pred=2
# 12- (16).png: GT=12, Pred=1
# 12- (16)_flipped.jpg: GT=12, Pred=0
# 12- (16)_flipped_flipped.jpg: GT=12, Pred=1
# 12- (16)_flipped_flipped_flipped.jpg: GT=12, Pred=0
# 12- (17).png: GT=12, Pred=1
# 12- (17)_flipped.jpg: GT=12, Pred=1
# 12- (17)_flipped_flipped.jpg: GT=12, Pred=1
# 12- (17)_flipped_flipped_flipped.jpg: GT=12, Pred=1
# 12- (18).png: GT=12, Pred=1
# 12- (18)_flipped.jpg: GT=12, Pred=0
# 12- (18)_flipped_flipped.jpg: GT=12, Pred=1
# 12- (18)_flipped_flipped_flipped.jpg: GT=12, Pred=0
# 12- (19).png: GT=12, Pred=1
# 12- (19)_flipped.jpg: GT=12, Pred=1
# 12- (19)_flipped_flipped.jpg: GT=12, Pred=1
# 12- (19)_flipped_flipped_flipped.jpg: GT=12, Pred=1
# 12- (2).png: GT=12, Pred=3
# 12- (2)_flipped.jpg: GT=12, Pred=3
# 12- (2)_flipped_flipped.jpg: GT=12, Pred=5
# 12- (2)_flipped_flipped_flipped.jpg: GT=12, Pred=3
# 12- (20).png: GT=12, Pred=1
# 12- (20)_flipped.jpg: GT=12, Pred=0
# 12- (20)_flipped_flipped.jpg: GT=12, Pred=1
# 12- (20)_flipped_flipped_flipped.jpg: GT=12, Pred=0
# 12- (21).png: GT=12, Pred=1
# 12- (21)_flipped.jpg: GT=12, Pred=1
# 12- (21)_flipped_flipped.jpg: GT=12, Pred=1
# 12- (21)_flipped_flipped_flipped.jpg: GT=12, Pred=1
# 12- (22).png: GT=12, Pred=1
# 12- (22)_flipped.jpg: GT=12, Pred=0
# 12- (22)_flipped_flipped.jpg: GT=12, Pred=1
# 12- (22)_flipped_flipped_flipped.jpg: GT=12, Pred=0
# 12- (23).png: GT=12, Pred=1
# 12- (23)_flipped.jpg: GT=12, Pred=1
# 12- (23)_flipped_flipped.jpg: GT=12, Pred=1
# 12- (23)_flipped_flipped_flipped.jpg: GT=12, Pred=1
# 12- (24).png: GT=12, Pred=1
# 12- (24)_flipped.jpg: GT=12, Pred=1
# 12- (24)_flipped_flipped.jpg: GT=12, Pred=1
# 12- (24)_flipped_flipped_flipped.jpg: GT=12, Pred=1
# 12- (25).png: GT=12, Pred=1
# 12- (25)_flipped.jpg: GT=12, Pred=1
# 12- (25)_flipped_flipped.jpg: GT=12, Pred=1
# 12- (25)_flipped_flipped_flipped.jpg: GT=12, Pred=1
# 12- (26).png: GT=12, Pred=1
# 12- (26)_flipped.jpg: GT=12, Pred=1
# 12- (26)_flipped_flipped.jpg: GT=12, Pred=1
# 12- (26)_flipped_flipped_flipped.jpg: GT=12, Pred=1
# 12- (27).png: GT=12, Pred=0
# 12- (27)_flipped.jpg: GT=12, Pred=0
# 12- (27)_flipped_flipped.jpg: GT=12, Pred=1
# 12- (27)_flipped_flipped_flipped.jpg: GT=12, Pred=0
# 12- (28).png: GT=12, Pred=1
# 12- (28)_flipped.jpg: GT=12, Pred=1
# 12- (28)_flipped_flipped.jpg: GT=12, Pred=1
# 12- (28)_flipped_flipped_flipped.jpg: GT=12, Pred=1
# 12- (29).png: GT=12, Pred=1
# 12- (29)_flipped.jpg: GT=12, Pred=1
# 12- (29)_flipped_flipped.jpg: GT=12, Pred=1
# 12- (29)_flipped_flipped_flipped.jpg: GT=12, Pred=1
# 12- (3).png: GT=12, Pred=3
# 12- (3)_flipped.jpg: GT=12, Pred=3
# 12- (3)_flipped_flipped.jpg: GT=12, Pred=3
# 12- (3)_flipped_flipped_flipped.jpg: GT=12, Pred=3
# 12- (30).png: GT=12, Pred=1
# 12- (30)_flipped.jpg: GT=12, Pred=1
# 12- (30)_flipped_flipped.jpg: GT=12, Pred=1
# 12- (30)_flipped_flipped_flipped.jpg: GT=12, Pred=1
# 12- (31).png: GT=12, Pred=1
# 12- (31)_flipped.jpg: GT=12, Pred=1
# 12- (31)_flipped_flipped.jpg: GT=12, Pred=1
# 12- (31)_flipped_flipped_flipped.jpg: GT=12, Pred=1
# 12- (32).png: GT=12, Pred=1
# 12- (32)_flipped.jpg: GT=12, Pred=1
# 12- (32)_flipped_flipped.jpg: GT=12, Pred=1
# 12- (32)_flipped_flipped_flipped.jpg: GT=12, Pred=1
# 12- (33).png: GT=12, Pred=1
# 12- (33)_flipped.jpg: GT=12, Pred=0
# 12- (33)_flipped_flipped.jpg: GT=12, Pred=1
# 12- (33)_flipped_flipped_flipped.jpg: GT=12, Pred=0
# 12- (34).png: GT=12, Pred=1
# 12- (34)_flipped.jpg: GT=12, Pred=1
# 12- (34)_flipped_flipped.jpg: GT=12, Pred=1
# 12- (34)_flipped_flipped_flipped.jpg: GT=12, Pred=1
# 12- (35).png: GT=12, Pred=1
# 12- (35)_flipped.jpg: GT=12, Pred=1
# 12- (35)_flipped_flipped.jpg: GT=12, Pred=1
# 12- (35)_flipped_flipped_flipped.jpg: GT=12, Pred=1
# 12- (36).png: GT=12, Pred=1
# 12- (36)_flipped.jpg: GT=12, Pred=1
# 12- (36)_flipped_flipped.jpg: GT=12, Pred=1
# 12- (36)_flipped_flipped_flipped.jpg: GT=12, Pred=1
# 12- (37).png: GT=12, Pred=1
# 12- (37)_flipped.jpg: GT=12, Pred=1
# 12- (37)_flipped_flipped.jpg: GT=12, Pred=1
# 12- (37)_flipped_flipped_flipped.jpg: GT=12, Pred=1
# 12- (38).png: GT=12, Pred=1
# 12- (38)_flipped.jpg: GT=12, Pred=1
# 12- (38)_flipped_flipped.jpg: GT=12, Pred=1
# 12- (38)_flipped_flipped_flipped.jpg: GT=12, Pred=1
# 12- (39).png: GT=12, Pred=1
# 12- (39)_flipped.jpg: GT=12, Pred=1
# 12- (39)_flipped_flipped.jpg: GT=12, Pred=1
# 12- (39)_flipped_flipped_flipped.jpg: GT=12, Pred=1
# 12- (4).png: GT=12, Pred=2
# 12- (4)_flipped.jpg: GT=12, Pred=3
# 12- (4)_flipped_flipped.jpg: GT=12, Pred=4
# 12- (4)_flipped_flipped_flipped.jpg: GT=12, Pred=3
# 12- (40).png: GT=12, Pred=1
# 12- (40)_flipped.jpg: GT=12, Pred=1
# 12- (40)_flipped_flipped.jpg: GT=12, Pred=1
# 12- (40)_flipped_flipped_flipped.jpg: GT=12, Pred=1
# 12- (41).png: GT=12, Pred=1
# 12- (41)_flipped.jpg: GT=12, Pred=2
# 12- (41)_flipped_flipped.jpg: GT=12, Pred=3
# 12- (41)_flipped_flipped_flipped.jpg: GT=12, Pred=2
# 12- (42).png: GT=12, Pred=0
# 12- (42)_flipped.jpg: GT=12, Pred=1
# 12- (42)_flipped_flipped.jpg: GT=12, Pred=3
# 12- (42)_flipped_flipped_flipped.jpg: GT=12, Pred=1
# 12- (43).png: GT=12, Pred=1
# 12- (43)_flipped.jpg: GT=12, Pred=2
# 12- (43)_flipped_flipped.jpg: GT=12, Pred=3
# 12- (43)_flipped_flipped_flipped.jpg: GT=12, Pred=2
# 12- (44).png: GT=12, Pred=2
# 12- (44)_flipped.jpg: GT=12, Pred=2
# 12- (44)_flipped_flipped.jpg: GT=12, Pred=2
# 12- (44)_flipped_flipped_flipped.jpg: GT=12, Pred=2
# 12- (45).png: GT=12, Pred=3
# 12- (45)_flipped.jpg: GT=12, Pred=2
# 12- (45)_flipped_flipped.jpg: GT=12, Pred=3
# 12- (45)_flipped_flipped_flipped.jpg: GT=12, Pred=2
# 12- (46).png: GT=12, Pred=2
# 12- (46)_flipped.jpg: GT=12, Pred=0
# 12- (46)_flipped_flipped.jpg: GT=12, Pred=2
# 12- (46)_flipped_flipped_flipped.jpg: GT=12, Pred=0
# 12- (47).png: GT=12, Pred=0
# 12- (47)_flipped.jpg: GT=12, Pred=3
# 12- (47)_flipped_flipped.jpg: GT=12, Pred=3
# 12- (47)_flipped_flipped_flipped.jpg: GT=12, Pred=3
# 12- (48).png: GT=12, Pred=1
# 12- (48)_flipped.jpg: GT=12, Pred=3
# 12- (48)_flipped_flipped.jpg: GT=12, Pred=4
# 12- (48)_flipped_flipped_flipped.jpg: GT=12, Pred=3
# 12- (49).png: GT=12, Pred=1
# 12- (49)_flipped.jpg: GT=12, Pred=2
# 12- (49)_flipped_flipped.jpg: GT=12, Pred=3
# 12- (49)_flipped_flipped_flipped.jpg: GT=12, Pred=2
# 12- (5).png: GT=12, Pred=3
# 12- (5)_flipped.jpg: GT=12, Pred=2
# 12- (5)_flipped_flipped.jpg: GT=12, Pred=3
# 12- (5)_flipped_flipped_flipped.jpg: GT=12, Pred=2
# 12- (50).png: GT=12, Pred=1
# 12- (50)_flipped.jpg: GT=12, Pred=1
# 12- (50)_flipped_flipped.jpg: GT=12, Pred=3
# 12- (50)_flipped_flipped_flipped.jpg: GT=12, Pred=1
# 12- (51).png: GT=12, Pred=3
# 12- (51)_flipped.jpg: GT=12, Pred=2
# 12- (51)_flipped_flipped.jpg: GT=12, Pred=2
# 12- (51)_flipped_flipped_flipped.jpg: GT=12, Pred=2
# 12- (52).png: GT=12, Pred=1
# 12- (52)_flipped.jpg: GT=12, Pred=2
# 12- (52)_flipped_flipped.jpg: GT=12, Pred=2
# 12- (52)_flipped_flipped_flipped.jpg: GT=12, Pred=2
# 12- (53).png: GT=12, Pred=1
# 12- (53)_flipped.jpg: GT=12, Pred=2
# 12- (53)_flipped_flipped.jpg: GT=12, Pred=2
# 12- (53)_flipped_flipped_flipped.jpg: GT=12, Pred=2
# 12- (54).png: GT=12, Pred=1
# 12- (54)_flipped.jpg: GT=12, Pred=3
# 12- (54)_flipped_flipped.jpg: GT=12, Pred=3
# 12- (54)_flipped_flipped_flipped.jpg: GT=12, Pred=3
# 12- (55).png: GT=12, Pred=2
# 12- (55)_flipped.jpg: GT=12, Pred=3
# 12- (55)_flipped_flipped.jpg: GT=12, Pred=3
# 12- (55)_flipped_flipped_flipped.jpg: GT=12, Pred=3
# 12- (56).png: GT=12, Pred=2
# 12- (56)_flipped.jpg: GT=12, Pred=3
# 12- (56)_flipped_flipped.jpg: GT=12, Pred=3
# 12- (56)_flipped_flipped_flipped.jpg: GT=12, Pred=3
# 12- (57).png: GT=12, Pred=0
# 12- (57)_flipped.jpg: GT=12, Pred=2
# 12- (57)_flipped_flipped.jpg: GT=12, Pred=2
# 12- (57)_flipped_flipped_flipped.jpg: GT=12, Pred=2
# 12- (58).png: GT=12, Pred=3
# 12- (58)_flipped.jpg: GT=12, Pred=2
# 12- (58)_flipped_flipped.jpg: GT=12, Pred=2
# 12- (58)_flipped_flipped_flipped.jpg: GT=12, Pred=2
# 12- (59).png: GT=12, Pred=2
# 12- (59)_flipped.jpg: GT=12, Pred=2
# 12- (59)_flipped_flipped.jpg: GT=12, Pred=2
# 12- (59)_flipped_flipped_flipped.jpg: GT=12, Pred=2
# 12- (6).png: GT=12, Pred=4
# 12- (6)_flipped.jpg: GT=12, Pred=3
# 12- (6)_flipped_flipped.jpg: GT=12, Pred=5
# 12- (6)_flipped_flipped_flipped.jpg: GT=12, Pred=3
# 12- (60).png: GT=12, Pred=2
# 12- (60)_flipped.jpg: GT=12, Pred=2
# 12- (60)_flipped_flipped.jpg: GT=12, Pred=4
# 12- (60)_flipped_flipped_flipped.jpg: GT=12, Pred=2
# 12- (61).png: GT=12, Pred=0
# 12- (61)_flipped.jpg: GT=12, Pred=2
# 12- (61)_flipped_flipped.jpg: GT=12, Pred=2
# 12- (61)_flipped_flipped_flipped.jpg: GT=12, Pred=2
# 12- (7).png: GT=12, Pred=3
# 12- (7)_flipped.jpg: GT=12, Pred=3
# 12- (7)_flipped_flipped.jpg: GT=12, Pred=3
# 12- (7)_flipped_flipped_flipped.jpg: GT=12, Pred=3
# 12- (8).png: GT=12, Pred=4
# 12- (8)_flipped.jpg: GT=12, Pred=2
# 12- (8)_flipped_flipped.jpg: GT=12, Pred=4
# 12- (8)_flipped_flipped_flipped.jpg: GT=12, Pred=2
# 12- (9).png: GT=12, Pred=3
# 12- (9)_flipped.jpg: GT=12, Pred=3
# 12- (9)_flipped_flipped.jpg: GT=12, Pred=3
# 12- (9)_flipped_flipped_flipped.jpg: GT=12, Pred=3
# 13- (1).png: GT=13, Pred=1
# 13- (1)_flipped.jpg: GT=13, Pred=1
# 13- (1)_flipped_flipped.jpg: GT=13, Pred=1
# 13- (1)_flipped_flipped_flipped.jpg: GT=13, Pred=1
# 13- (10).png: GT=13, Pred=1
# 13- (10)_flipped.jpg: GT=13, Pred=1
# 13- (10)_flipped_flipped.jpg: GT=13, Pred=1
# 13- (10)_flipped_flipped_flipped.jpg: GT=13, Pred=1
# 13- (11).png: GT=13, Pred=1
# 13- (11)_flipped.jpg: GT=13, Pred=1
# 13- (11)_flipped_flipped.jpg: GT=13, Pred=1
# 13- (11)_flipped_flipped_flipped.jpg: GT=13, Pred=1
# 13- (12).png: GT=13, Pred=1
# 13- (12)_flipped.jpg: GT=13, Pred=1
# 13- (12)_flipped_flipped.jpg: GT=13, Pred=1
# 13- (12)_flipped_flipped_flipped.jpg: GT=13, Pred=1
# 13- (13).png: GT=13, Pred=1
# 13- (13)_flipped.jpg: GT=13, Pred=1
# 13- (13)_flipped_flipped.jpg: GT=13, Pred=1
# 13- (13)_flipped_flipped_flipped.jpg: GT=13, Pred=1
# 13- (14).png: GT=13, Pred=1
# 13- (14)_flipped.jpg: GT=13, Pred=1
# 13- (14)_flipped_flipped.jpg: GT=13, Pred=1
# 13- (14)_flipped_flipped_flipped.jpg: GT=13, Pred=1
# 13- (15).png: GT=13, Pred=1
# 13- (15)_flipped.jpg: GT=13, Pred=1
# 13- (15)_flipped_flipped.jpg: GT=13, Pred=1
# 13- (15)_flipped_flipped_flipped.jpg: GT=13, Pred=1
# 13- (16).png: GT=13, Pred=1
# 13- (16)_flipped.jpg: GT=13, Pred=1
# 13- (16)_flipped_flipped.jpg: GT=13, Pred=1
# 13- (16)_flipped_flipped_flipped.jpg: GT=13, Pred=1
# 13- (17).png: GT=13, Pred=1
# 13- (17)_flipped.jpg: GT=13, Pred=0
# 13- (17)_flipped_flipped.jpg: GT=13, Pred=0
# 13- (17)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (18).png: GT=13, Pred=1
# 13- (18)_flipped.jpg: GT=13, Pred=0
# 13- (18)_flipped_flipped.jpg: GT=13, Pred=0
# 13- (18)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (19).png: GT=13, Pred=1
# 13- (19)_flipped.jpg: GT=13, Pred=0
# 13- (19)_flipped_flipped.jpg: GT=13, Pred=1
# 13- (19)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (2).png: GT=13, Pred=1
# 13- (2)_flipped.jpg: GT=13, Pred=0
# 13- (2)_flipped_flipped.jpg: GT=13, Pred=1
# 13- (2)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (20).png: GT=13, Pred=1
# 13- (20)_flipped.jpg: GT=13, Pred=0
# 13- (20)_flipped_flipped.jpg: GT=13, Pred=0
# 13- (20)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (21).png: GT=13, Pred=1
# 13- (21)_flipped.jpg: GT=13, Pred=1
# 13- (21)_flipped_flipped.jpg: GT=13, Pred=1
# 13- (21)_flipped_flipped_flipped.jpg: GT=13, Pred=1
# 13- (22).png: GT=13, Pred=1
# 13- (22)_flipped.jpg: GT=13, Pred=0
# 13- (22)_flipped_flipped.jpg: GT=13, Pred=0
# 13- (22)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (23).png: GT=13, Pred=1
# 13- (23)_flipped.jpg: GT=13, Pred=1
# 13- (23)_flipped_flipped.jpg: GT=13, Pred=1
# 13- (23)_flipped_flipped_flipped.jpg: GT=13, Pred=1
# 13- (24).png: GT=13, Pred=1
# 13- (24)_flipped.jpg: GT=13, Pred=0
# 13- (24)_flipped_flipped.jpg: GT=13, Pred=0
# 13- (24)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (25).png: GT=13, Pred=1
# 13- (25)_flipped.jpg: GT=13, Pred=0
# 13- (25)_flipped_flipped.jpg: GT=13, Pred=1
# 13- (25)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (26).png: GT=13, Pred=1
# 13- (26)_flipped.jpg: GT=13, Pred=0
# 13- (26)_flipped_flipped.jpg: GT=13, Pred=1
# 13- (26)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (27).png: GT=13, Pred=1
# 13- (27)_flipped.jpg: GT=13, Pred=1
# 13- (27)_flipped_flipped.jpg: GT=13, Pred=1
# 13- (27)_flipped_flipped_flipped.jpg: GT=13, Pred=1
# 13- (28).png: GT=13, Pred=1
# 13- (28)_flipped.jpg: GT=13, Pred=1
# 13- (28)_flipped_flipped.jpg: GT=13, Pred=1
# 13- (28)_flipped_flipped_flipped.jpg: GT=13, Pred=1
# 13- (29).png: GT=13, Pred=1
# 13- (29)_flipped.jpg: GT=13, Pred=0
# 13- (29)_flipped_flipped.jpg: GT=13, Pred=0
# 13- (29)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (3).png: GT=13, Pred=1
# 13- (3)_flipped.jpg: GT=13, Pred=1
# 13- (3)_flipped_flipped.jpg: GT=13, Pred=1
# 13- (3)_flipped_flipped_flipped.jpg: GT=13, Pred=1
# 13- (30).png: GT=13, Pred=1
# 13- (30)_flipped.jpg: GT=13, Pred=2
# 13- (30)_flipped_flipped.jpg: GT=13, Pred=2
# 13- (30)_flipped_flipped_flipped.jpg: GT=13, Pred=2
# 13- (31).png: GT=13, Pred=0
# 13- (31)_flipped.jpg: GT=13, Pred=2
# 13- (31)_flipped_flipped.jpg: GT=13, Pred=2
# 13- (31)_flipped_flipped_flipped.jpg: GT=13, Pred=2
# 13- (32).png: GT=13, Pred=0
# 13- (32)_flipped.jpg: GT=13, Pred=2
# 13- (32)_flipped_flipped.jpg: GT=13, Pred=2
# 13- (32)_flipped_flipped_flipped.jpg: GT=13, Pred=2
# 13- (33).png: GT=13, Pred=1
# 13- (33)_flipped.jpg: GT=13, Pred=2
# 13- (33)_flipped_flipped.jpg: GT=13, Pred=2
# 13- (33)_flipped_flipped_flipped.jpg: GT=13, Pred=2
# 13- (34).png: GT=13, Pred=0
# 13- (34)_flipped.jpg: GT=13, Pred=2
# 13- (34)_flipped_flipped.jpg: GT=13, Pred=3
# 13- (34)_flipped_flipped_flipped.jpg: GT=13, Pred=2
# 13- (35).png: GT=13, Pred=0
# 13- (35)_flipped.jpg: GT=13, Pred=2
# 13- (35)_flipped_flipped.jpg: GT=13, Pred=2
# 13- (35)_flipped_flipped_flipped.jpg: GT=13, Pred=2
# 13- (36).png: GT=13, Pred=0
# 13- (36)_flipped.jpg: GT=13, Pred=2
# 13- (36)_flipped_flipped.jpg: GT=13, Pred=2
# 13- (36)_flipped_flipped_flipped.jpg: GT=13, Pred=2
# 13- (37).png: GT=13, Pred=0
# 13- (37)_flipped.jpg: GT=13, Pred=3
# 13- (37)_flipped_flipped.jpg: GT=13, Pred=3
# 13- (37)_flipped_flipped_flipped.jpg: GT=13, Pred=3
# 13- (38).png: GT=13, Pred=0
# 13- (38)_flipped.jpg: GT=13, Pred=2
# 13- (38)_flipped_flipped.jpg: GT=13, Pred=3
# 13- (38)_flipped_flipped_flipped.jpg: GT=13, Pred=2
# 13- (39).png: GT=13, Pred=0
# 13- (39)_flipped.jpg: GT=13, Pred=3
# 13- (39)_flipped_flipped.jpg: GT=13, Pred=3
# 13- (39)_flipped_flipped_flipped.jpg: GT=13, Pred=3
# 13- (4).png: GT=13, Pred=1
# 13- (4)_flipped.jpg: GT=13, Pred=0
# 13- (4)_flipped_flipped.jpg: GT=13, Pred=1
# 13- (4)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (40).png: GT=13, Pred=1
# 13- (40)_flipped.jpg: GT=13, Pred=2
# 13- (40)_flipped_flipped.jpg: GT=13, Pred=2
# 13- (40)_flipped_flipped_flipped.jpg: GT=13, Pred=2
# 13- (41).png: GT=13, Pred=0
# 13- (41)_flipped.jpg: GT=13, Pred=2
# 13- (41)_flipped_flipped.jpg: GT=13, Pred=3
# 13- (41)_flipped_flipped_flipped.jpg: GT=13, Pred=2
# 13- (42).png: GT=13, Pred=1
# 13- (42)_flipped.jpg: GT=13, Pred=3
# 13- (42)_flipped_flipped.jpg: GT=13, Pred=3
# 13- (42)_flipped_flipped_flipped.jpg: GT=13, Pred=3
# 13- (43).png: GT=13, Pred=1
# 13- (43)_flipped.jpg: GT=13, Pred=0
# 13- (43)_flipped_flipped.jpg: GT=13, Pred=0
# 13- (43)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (44).png: GT=13, Pred=0
# 13- (44)_flipped.jpg: GT=13, Pred=1
# 13- (44)_flipped_flipped.jpg: GT=13, Pred=3
# 13- (44)_flipped_flipped_flipped.jpg: GT=13, Pred=1
# 13- (45).png: GT=13, Pred=0
# 13- (45)_flipped.jpg: GT=13, Pred=2
# 13- (45)_flipped_flipped.jpg: GT=13, Pred=2
# 13- (45)_flipped_flipped_flipped.jpg: GT=13, Pred=2
# 13- (46).png: GT=13, Pred=0
# 13- (46)_flipped.jpg: GT=13, Pred=3
# 13- (46)_flipped_flipped.jpg: GT=13, Pred=3
# 13- (46)_flipped_flipped_flipped.jpg: GT=13, Pred=3
# 13- (47).png: GT=13, Pred=0
# 13- (47)_flipped.jpg: GT=13, Pred=3
# 13- (47)_flipped_flipped.jpg: GT=13, Pred=3
# 13- (47)_flipped_flipped_flipped.jpg: GT=13, Pred=3
# 13- (48).png: GT=13, Pred=0
# 13- (48)_flipped.jpg: GT=13, Pred=2
# 13- (48)_flipped_flipped.jpg: GT=13, Pred=2
# 13- (48)_flipped_flipped_flipped.jpg: GT=13, Pred=2
# 13- (49).png: GT=13, Pred=0
# 13- (49)_flipped.jpg: GT=13, Pred=3
# 13- (49)_flipped_flipped.jpg: GT=13, Pred=3
# 13- (49)_flipped_flipped_flipped.jpg: GT=13, Pred=3
# 13- (5).png: GT=13, Pred=1
# 13- (5)_flipped.jpg: GT=13, Pred=1
# 13- (5)_flipped_flipped.jpg: GT=13, Pred=1
# 13- (5)_flipped_flipped_flipped.jpg: GT=13, Pred=1
# 13- (6).png: GT=13, Pred=1
# 13- (6)_flipped.jpg: GT=13, Pred=1
# 13- (6)_flipped_flipped.jpg: GT=13, Pred=1
# 13- (6)_flipped_flipped_flipped.jpg: GT=13, Pred=1
# 13- (7).png: GT=13, Pred=1
# 13- (7)_flipped.jpg: GT=13, Pred=1
# 13- (7)_flipped_flipped.jpg: GT=13, Pred=1
# 13- (7)_flipped_flipped_flipped.jpg: GT=13, Pred=1
# 13- (8).png: GT=13, Pred=1
# 13- (8)_flipped.jpg: GT=13, Pred=1
# 13- (8)_flipped_flipped.jpg: GT=13, Pred=1
# 13- (8)_flipped_flipped_flipped.jpg: GT=13, Pred=1
# 13- (9).png: GT=13, Pred=1
# 13- (9)_flipped.jpg: GT=13, Pred=1
# 13- (9)_flipped_flipped.jpg: GT=13, Pred=1
# 13- (9)_flipped_flipped_flipped.jpg: GT=13, Pred=1
# 14- (1).png: GT=14, Pred=0
# 14- (1)_flipped.jpg: GT=14, Pred=0
# 14- (1)_flipped_flipped.jpg: GT=14, Pred=0
# 14- (1)_flipped_flipped_flipped.jpg: GT=14, Pred=0
# 14- (10).png: GT=14, Pred=0
# 14- (10)_flipped.jpg: GT=14, Pred=0
# 14- (10)_flipped_flipped.jpg: GT=14, Pred=0
# 14- (10)_flipped_flipped_flipped.jpg: GT=14, Pred=0
# 14- (11).png: GT=14, Pred=0
# 14- (11)_flipped.jpg: GT=14, Pred=0
# 14- (11)_flipped_flipped.jpg: GT=14, Pred=0
# 14- (11)_flipped_flipped_flipped.jpg: GT=14, Pred=0
# 14- (12).png: GT=14, Pred=0
# 14- (12)_flipped.jpg: GT=14, Pred=0
# 14- (12)_flipped_flipped.jpg: GT=14, Pred=0
# 14- (12)_flipped_flipped_flipped.jpg: GT=14, Pred=0
# 14- (13).png: GT=14, Pred=0
# 14- (13)_flipped.jpg: GT=14, Pred=0
# 14- (13)_flipped_flipped.jpg: GT=14, Pred=0
# ...
# 8- (39)_flipped_flipped.jpg: GT=8, Pred=2
# 8- (39)_flipped_flipped_flipped.jpg: GT=8, Pred=1
# 8- (4).png: GT=8, Pred=2
# 8- (4)_flipped.jpg: GT=8, Pred=3
# 8- (4)_flipped_flipped.jpg: GT=8, Pred=4
# 8- (4)_flipped_flipped_flipped.jpg: GT=8, Pred=3
# 8- (40).png: GT=8, Pred=1
# 8- (40)_flipped.jpg: GT=8, Pred=1
# 8- (40)_flipped_flipped.jpg: GT=8, Pred=2
# 8- (40)_flipped_flipped_flipped.jpg: GT=8, Pred=1
# 8- (41).png: GT=8, Pred=2
# 8- (41)_flipped.jpg: GT=8, Pred=0
# 8- (41)_flipped_flipped.jpg: GT=8, Pred=0
# 8- (41)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (42).png: GT=8, Pred=0
# 8- (42)_flipped.jpg: GT=8, Pred=2
# 8- (42)_flipped_flipped.jpg: GT=8, Pred=2
# 8- (42)_flipped_flipped_flipped.jpg: GT=8, Pred=2
# 8- (43).png: GT=8, Pred=2
# 8- (43)_flipped.jpg: GT=8, Pred=2
# 8- (43)_flipped_flipped.jpg: GT=8, Pred=1
# 8- (43)_flipped_flipped_flipped.jpg: GT=8, Pred=2
# 8- (44).png: GT=8, Pred=0
# 8- (44)_flipped.jpg: GT=8, Pred=0
# 8- (44)_flipped_flipped.jpg: GT=8, Pred=0
# 8- (44)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (45).png: GT=8, Pred=0
# 8- (45)_flipped.jpg: GT=8, Pred=0
# 8- (45)_flipped_flipped.jpg: GT=8, Pred=0
# 8- (45)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (46).png: GT=8, Pred=0
# 8- (46)_flipped.jpg: GT=8, Pred=0
# 8- (46)_flipped_flipped.jpg: GT=8, Pred=0
# 8- (46)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (47).png: GT=8, Pred=0
# 8- (47)_flipped.jpg: GT=8, Pred=0
# 8- (47)_flipped_flipped.jpg: GT=8, Pred=0
# 8- (47)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (48).png: GT=8, Pred=0
# 8- (48)_flipped.jpg: GT=8, Pred=0
# 8- (48)_flipped_flipped.jpg: GT=8, Pred=3
# 8- (48)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (49).png: GT=8, Pred=1
# 8- (49)_flipped.jpg: GT=8, Pred=0
# 8- (49)_flipped_flipped.jpg: GT=8, Pred=0
# 8- (49)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (5).png: GT=8, Pred=2
# 8- (5)_flipped.jpg: GT=8, Pred=2
# 8- (5)_flipped_flipped.jpg: GT=8, Pred=2
# 8- (5)_flipped_flipped_flipped.jpg: GT=8, Pred=2
# 8- (50).png: GT=8, Pred=0
# 8- (50)_flipped.jpg: GT=8, Pred=0
# 8- (50)_flipped_flipped.jpg: GT=8, Pred=0
# 8- (50)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (51).png: GT=8, Pred=0
# 8- (51)_flipped.jpg: GT=8, Pred=0
# 8- (51)_flipped_flipped.jpg: GT=8, Pred=0
# 8- (51)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (52).png: GT=8, Pred=0
# 8- (52)_flipped.jpg: GT=8, Pred=0
# 8- (52)_flipped_flipped.jpg: GT=8, Pred=0
# 8- (52)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (53).png: GT=8, Pred=0
# 8- (53)_flipped.jpg: GT=8, Pred=0
# 8- (53)_flipped_flipped.jpg: GT=8, Pred=0
# 8- (53)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (54).png: GT=8, Pred=0
# 8- (54)_flipped.jpg: GT=8, Pred=0
# 8- (54)_flipped_flipped.jpg: GT=8, Pred=0
# 8- (54)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (55).png: GT=8, Pred=0
# 8- (55)_flipped.jpg: GT=8, Pred=0
# 8- (55)_flipped_flipped.jpg: GT=8, Pred=0
# 8- (55)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (56).png: GT=8, Pred=1
# 8- (56)_flipped.jpg: GT=8, Pred=0
# 8- (56)_flipped_flipped.jpg: GT=8, Pred=1
# 8- (56)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (57).png: GT=8, Pred=0
# 8- (57)_flipped.jpg: GT=8, Pred=0
# 8- (57)_flipped_flipped.jpg: GT=8, Pred=0
# 8- (57)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (58).png: GT=8, Pred=1
# 8- (58)_flipped.jpg: GT=8, Pred=3
# 8- (58)_flipped_flipped.jpg: GT=8, Pred=3
# 8- (58)_flipped_flipped_flipped.jpg: GT=8, Pred=3
# 8- (59).png: GT=8, Pred=0
# 8- (59)_flipped.jpg: GT=8, Pred=0
# 8- (59)_flipped_flipped.jpg: GT=8, Pred=0
# 8- (59)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (6).png: GT=8, Pred=2
# 8- (6)_flipped.jpg: GT=8, Pred=2
# 8- (6)_flipped_flipped.jpg: GT=8, Pred=2
# 8- (6)_flipped_flipped_flipped.jpg: GT=8, Pred=2
# 8- (60).png: GT=8, Pred=0
# 8- (60)_flipped.jpg: GT=8, Pred=1
# 8- (60)_flipped_flipped.jpg: GT=8, Pred=0
# 8- (60)_flipped_flipped_flipped.jpg: GT=8, Pred=1
# 8- (61).png: GT=8, Pred=1
# 8- (61)_flipped.jpg: GT=8, Pred=1
# 8- (61)_flipped_flipped.jpg: GT=8, Pred=2
# 8- (61)_flipped_flipped_flipped.jpg: GT=8, Pred=1
# 8- (62).png: GT=8, Pred=2
# 8- (62)_flipped.jpg: GT=8, Pred=2
# 8- (62)_flipped_flipped.jpg: GT=8, Pred=2
# 8- (62)_flipped_flipped_flipped.jpg: GT=8, Pred=2
# 8- (7).png: GT=8, Pred=3
# 8- (7)_flipped.jpg: GT=8, Pred=3
# 8- (7)_flipped_flipped.jpg: GT=8, Pred=5
# 8- (7)_flipped_flipped_flipped.jpg: GT=8, Pred=3
# 8- (8).png: GT=8, Pred=2
# 8- (8)_flipped.jpg: GT=8, Pred=2
# 8- (8)_flipped_flipped.jpg: GT=8, Pred=3
# 8- (8)_flipped_flipped_flipped.jpg: GT=8, Pred=2
# 8- (9).png: GT=8, Pred=2
# 8- (9)_flipped.jpg: GT=8, Pred=2
# 8- (9)_flipped_flipped.jpg: GT=8, Pred=3
# 8- (9)_flipped_flipped_flipped.jpg: GT=8, Pred=2
# 9- (1).png: GT=9, Pred=0
# 9- (1)_flipped.jpg: GT=9, Pred=4
# 9- (1)_flipped_flipped.jpg: GT=9, Pred=3
# 9- (1)_flipped_flipped_flipped.jpg: GT=9, Pred=4
# 9- (10).png: GT=9, Pred=1
# 9- (10)_flipped.jpg: GT=9, Pred=3
# 9- (10)_flipped_flipped.jpg: GT=9, Pred=2
# 9- (10)_flipped_flipped_flipped.jpg: GT=9, Pred=3
# 9- (11).png: GT=9, Pred=1
# 9- (11)_flipped.jpg: GT=9, Pred=2
# 9- (11)_flipped_flipped.jpg: GT=9, Pred=4
# 9- (11)_flipped_flipped_flipped.jpg: GT=9, Pred=2
# 9- (12).png: GT=9, Pred=3
# 9- (12)_flipped.jpg: GT=9, Pred=2
# 9- (12)_flipped_flipped.jpg: GT=9, Pred=2
# 9- (12)_flipped_flipped_flipped.jpg: GT=9, Pred=2
# 9- (13).png: GT=9, Pred=0
# 9- (13)_flipped.jpg: GT=9, Pred=4
# 9- (13)_flipped_flipped.jpg: GT=9, Pred=3
# 9- (13)_flipped_flipped_flipped.jpg: GT=9, Pred=4
# 9- (14).png: GT=9, Pred=0
# 9- (14)_flipped.jpg: GT=9, Pred=3
# 9- (14)_flipped_flipped.jpg: GT=9, Pred=2
# 9- (14)_flipped_flipped_flipped.jpg: GT=9, Pred=3
# 9- (15).png: GT=9, Pred=0
# 9- (15)_flipped.jpg: GT=9, Pred=1
# 9- (15)_flipped_flipped.jpg: GT=9, Pred=2
# 9- (15)_flipped_flipped_flipped.jpg: GT=9, Pred=1
# 9- (16).png: GT=9, Pred=3
# 9- (16)_flipped.jpg: GT=9, Pred=4
# 9- (16)_flipped_flipped.jpg: GT=9, Pred=4
# 9- (16)_flipped_flipped_flipped.jpg: GT=9, Pred=4
# 9- (17).png: GT=9, Pred=3
# 9- (17)_flipped.jpg: GT=9, Pred=4
# 9- (17)_flipped_flipped.jpg: GT=9, Pred=3
# 9- (17)_flipped_flipped_flipped.jpg: GT=9, Pred=4
# 9- (18).png: GT=9, Pred=4
# 9- (18)_flipped.jpg: GT=9, Pred=5
# 9- (18)_flipped_flipped.jpg: GT=9, Pred=4
# 9- (18)_flipped_flipped_flipped.jpg: GT=9, Pred=5
# 9- (19).png: GT=9, Pred=1
# 9- (19)_flipped.jpg: GT=9, Pred=2
# 9- (19)_flipped_flipped.jpg: GT=9, Pred=4
# 9- (19)_flipped_flipped_flipped.jpg: GT=9, Pred=2
# 9- (2).png: GT=9, Pred=1
# 9- (2)_flipped.jpg: GT=9, Pred=3
# 9- (2)_flipped_flipped.jpg: GT=9, Pred=2
# 9- (2)_flipped_flipped_flipped.jpg: GT=9, Pred=3
# 9- (20).png: GT=9, Pred=1
# 9- (20)_flipped.jpg: GT=9, Pred=4
# 9- (20)_flipped_flipped.jpg: GT=9, Pred=3
# 9- (20)_flipped_flipped_flipped.jpg: GT=9, Pred=4
# 9- (21).png: GT=9, Pred=3
# 9- (21)_flipped.jpg: GT=9, Pred=3
# 9- (21)_flipped_flipped.jpg: GT=9, Pred=3
# 9- (21)_flipped_flipped_flipped.jpg: GT=9, Pred=3
# 9- (22).png: GT=9, Pred=0
# 9- (22)_flipped.jpg: GT=9, Pred=3
# 9- (22)_flipped_flipped.jpg: GT=9, Pred=3
# 9- (22)_flipped_flipped_flipped.jpg: GT=9, Pred=3
# 9- (23).png: GT=9, Pred=1
# 9- (23)_flipped.jpg: GT=9, Pred=3
# 9- (23)_flipped_flipped.jpg: GT=9, Pred=2
# 9- (23)_flipped_flipped_flipped.jpg: GT=9, Pred=3
# 9- (24).png: GT=9, Pred=1
# 9- (24)_flipped.jpg: GT=9, Pred=1
# 9- (24)_flipped_flipped.jpg: GT=9, Pred=2
# 9- (24)_flipped_flipped_flipped.jpg: GT=9, Pred=1
# 9- (25).png: GT=9, Pred=1
# 9- (25)_flipped.jpg: GT=9, Pred=2
# 9- (25)_flipped_flipped.jpg: GT=9, Pred=2
# 9- (25)_flipped_flipped_flipped.jpg: GT=9, Pred=2
# 9- (26).png: GT=9, Pred=1
# 9- (26)_flipped.jpg: GT=9, Pred=3
# 9- (26)_flipped_flipped.jpg: GT=9, Pred=1
# 9- (26)_flipped_flipped_flipped.jpg: GT=9, Pred=3
# 9- (27).png: GT=9, Pred=0
# 9- (27)_flipped.jpg: GT=9, Pred=2
# 9- (27)_flipped_flipped.jpg: GT=9, Pred=4
# 9- (27)_flipped_flipped_flipped.jpg: GT=9, Pred=2
# 9- (28).png: GT=9, Pred=0
# 9- (28)_flipped.jpg: GT=9, Pred=0
# 9- (28)_flipped_flipped.jpg: GT=9, Pred=3
# 9- (28)_flipped_flipped_flipped.jpg: GT=9, Pred=0
# 9- (29).png: GT=9, Pred=1
# 9- (29)_flipped.jpg: GT=9, Pred=2
# 9- (29)_flipped_flipped.jpg: GT=9, Pred=1
# 9- (29)_flipped_flipped_flipped.jpg: GT=9, Pred=2
# 9- (3).png: GT=9, Pred=0
# 9- (3)_flipped.jpg: GT=9, Pred=2
# 9- (3)_flipped_flipped.jpg: GT=9, Pred=5
# 9- (3)_flipped_flipped_flipped.jpg: GT=9, Pred=2
# 9- (30).png: GT=9, Pred=2
# 9- (30)_flipped.jpg: GT=9, Pred=0
# 9- (30)_flipped_flipped.jpg: GT=9, Pred=1
# 9- (30)_flipped_flipped_flipped.jpg: GT=9, Pred=0
# 9- (31).png: GT=9, Pred=2
# 9- (31)_flipped.jpg: GT=9, Pred=4
# 9- (31)_flipped_flipped.jpg: GT=9, Pred=1
# 9- (31)_flipped_flipped_flipped.jpg: GT=9, Pred=4
# 9- (32).png: GT=9, Pred=4
# 9- (32)_flipped.jpg: GT=9, Pred=4
# 9- (32)_flipped_flipped.jpg: GT=9, Pred=2
# 9- (32)_flipped_flipped_flipped.jpg: GT=9, Pred=4
# 9- (33).png: GT=9, Pred=3
# 9- (33)_flipped.jpg: GT=9, Pred=2
# 9- (33)_flipped_flipped.jpg: GT=9, Pred=2
# 9- (33)_flipped_flipped_flipped.jpg: GT=9, Pred=2
# 9- (34).png: GT=9, Pred=0
# 9- (34)_flipped.jpg: GT=9, Pred=3
# 9- (34)_flipped_flipped.jpg: GT=9, Pred=3
# 9- (34)_flipped_flipped_flipped.jpg: GT=9, Pred=3
# 9- (35).png: GT=9, Pred=4
# 9- (35)_flipped.jpg: GT=9, Pred=4
# 9- (35)_flipped_flipped.jpg: GT=9, Pred=2
# 9- (35)_flipped_flipped_flipped.jpg: GT=9, Pred=4
# 9- (36).png: GT=9, Pred=1
# 9- (36)_flipped.jpg: GT=9, Pred=5
# 9- (36)_flipped_flipped.jpg: GT=9, Pred=2
# 9- (36)_flipped_flipped_flipped.jpg: GT=9, Pred=5
# 9- (37).png: GT=9, Pred=1
# 9- (37)_flipped.jpg: GT=9, Pred=3
# 9- (37)_flipped_flipped.jpg: GT=9, Pred=3
# 9- (37)_flipped_flipped_flipped.jpg: GT=9, Pred=3
# 9- (38).png: GT=9, Pred=0
# 9- (38)_flipped.jpg: GT=9, Pred=2
# 9- (38)_flipped_flipped.jpg: GT=9, Pred=3
# 9- (38)_flipped_flipped_flipped.jpg: GT=9, Pred=2
# 9- (39).png: GT=9, Pred=1
# 9- (39)_flipped.jpg: GT=9, Pred=2
# 9- (39)_flipped_flipped.jpg: GT=9, Pred=2
# 9- (39)_flipped_flipped_flipped.jpg: GT=9, Pred=2
# 9- (4).png: GT=9, Pred=1
# 9- (4)_flipped.jpg: GT=9, Pred=1
# 9- (4)_flipped_flipped.jpg: GT=9, Pred=1
# 9- (4)_flipped_flipped_flipped.jpg: GT=9, Pred=1
# 9- (40).png: GT=9, Pred=6
# 9- (40)_flipped.jpg: GT=9, Pred=4
# 9- (40)_flipped_flipped.jpg: GT=9, Pred=2
# 9- (40)_flipped_flipped_flipped.jpg: GT=9, Pred=4
# 9- (41).png: GT=9, Pred=0
# 9- (41)_flipped.jpg: GT=9, Pred=4
# 9- (41)_flipped_flipped.jpg: GT=9, Pred=3
# 9- (41)_flipped_flipped_flipped.jpg: GT=9, Pred=4
# 9- (42).png: GT=9, Pred=3
# 9- (42)_flipped.jpg: GT=9, Pred=2
# 9- (42)_flipped_flipped.jpg: GT=9, Pred=4
# 9- (42)_flipped_flipped_flipped.jpg: GT=9, Pred=2
# 9- (43).png: GT=9, Pred=4
# 9- (43)_flipped.jpg: GT=9, Pred=5
# 9- (43)_flipped_flipped.jpg: GT=9, Pred=3
# 9- (43)_flipped_flipped_flipped.jpg: GT=9, Pred=5
# 9- (44).png: GT=9, Pred=2
# 9- (44)_flipped.jpg: GT=9, Pred=2
# 9- (44)_flipped_flipped.jpg: GT=9, Pred=3
# 9- (44)_flipped_flipped_flipped.jpg: GT=9, Pred=2
# 9- (45).png: GT=9, Pred=3
# 9- (45)_flipped.jpg: GT=9, Pred=5
# 9- (45)_flipped_flipped.jpg: GT=9, Pred=4
# 9- (45)_flipped_flipped_flipped.jpg: GT=9, Pred=5
# 9- (46).png: GT=9, Pred=4
# 9- (46)_flipped.jpg: GT=9, Pred=5
# 9- (46)_flipped_flipped.jpg: GT=9, Pred=4
# 9- (46)_flipped_flipped_flipped.jpg: GT=9, Pred=5
# 9- (47).png: GT=9, Pred=0
# 9- (47)_flipped.jpg: GT=9, Pred=4
# 9- (47)_flipped_flipped.jpg: GT=9, Pred=3
# 9- (47)_flipped_flipped_flipped.jpg: GT=9, Pred=4
# 9- (48).png: GT=9, Pred=1
# 9- (48)_flipped.jpg: GT=9, Pred=6
# 9- (48)_flipped_flipped.jpg: GT=9, Pred=1
# 9- (48)_flipped_flipped_flipped.jpg: GT=9, Pred=6
# 9- (49).png: GT=9, Pred=1
# 9- (49)_flipped.jpg: GT=9, Pred=3
# 9- (49)_flipped_flipped.jpg: GT=9, Pred=3
# 9- (49)_flipped_flipped_flipped.jpg: GT=9, Pred=3
# 9- (5).png: GT=9, Pred=3
# 9- (5)_flipped.jpg: GT=9, Pred=4
# 9- (5)_flipped_flipped.jpg: GT=9, Pred=4
# 9- (5)_flipped_flipped_flipped.jpg: GT=9, Pred=4
# 9- (50).png: GT=9, Pred=1
# 9- (50)_flipped.jpg: GT=9, Pred=4
# 9- (50)_flipped_flipped.jpg: GT=9, Pred=3
# 9- (50)_flipped_flipped_flipped.jpg: GT=9, Pred=4
# 9- (51).png: GT=9, Pred=1
# 9- (51)_flipped.jpg: GT=9, Pred=3
# 9- (51)_flipped_flipped.jpg: GT=9, Pred=1
# 9- (51)_flipped_flipped_flipped.jpg: GT=9, Pred=3
# 9- (52).png: GT=9, Pred=0
# 9- (52)_flipped.jpg: GT=9, Pred=2
# 9- (52)_flipped_flipped.jpg: GT=9, Pred=3
# 9- (52)_flipped_flipped_flipped.jpg: GT=9, Pred=2
# 9- (53).png: GT=9, Pred=1
# 9- (53)_flipped.jpg: GT=9, Pred=2
# 9- (53)_flipped_flipped.jpg: GT=9, Pred=3
# 9- (53)_flipped_flipped_flipped.jpg: GT=9, Pred=2
# 9- (54).png: GT=9, Pred=1
# 9- (54)_flipped.jpg: GT=9, Pred=3
# 9- (54)_flipped_flipped.jpg: GT=9, Pred=4
# 9- (54)_flipped_flipped_flipped.jpg: GT=9, Pred=3
# 9- (55).png: GT=9, Pred=0
# 9- (55)_flipped.jpg: GT=9, Pred=5
# 9- (55)_flipped_flipped.jpg: GT=9, Pred=3
# 9- (55)_flipped_flipped_flipped.jpg: GT=9, Pred=5
# 9- (56).png: GT=9, Pred=3
# 9- (56)_flipped.jpg: GT=9, Pred=3
# 9- (56)_flipped_flipped.jpg: GT=9, Pred=5
# 9- (56)_flipped_flipped_flipped.jpg: GT=9, Pred=3
# 9- (57).png: GT=9, Pred=5
# 9- (57)_flipped.jpg: GT=9, Pred=4
# 9- (57)_flipped_flipped.jpg: GT=9, Pred=3
# 9- (57)_flipped_flipped_flipped.jpg: GT=9, Pred=4
# 9- (58).png: GT=9, Pred=3
# 9- (58)_flipped.jpg: GT=9, Pred=4
# 9- (58)_flipped_flipped.jpg: GT=9, Pred=3
# 9- (58)_flipped_flipped_flipped.jpg: GT=9, Pred=4
# 9- (59).png: GT=9, Pred=2
# 9- (59)_flipped.jpg: GT=9, Pred=3
# 9- (59)_flipped_flipped.jpg: GT=9, Pred=3
# 9- (59)_flipped_flipped_flipped.jpg: GT=9, Pred=3
# 9- (6).png: GT=9, Pred=3
# 9- (6)_flipped.jpg: GT=9, Pred=3
# 9- (6)_flipped_flipped.jpg: GT=9, Pred=4
# 9- (6)_flipped_flipped_flipped.jpg: GT=9, Pred=3
# 9- (60).png: GT=9, Pred=0
# 9- (60)_flipped.jpg: GT=9, Pred=3
# 9- (60)_flipped_flipped.jpg: GT=9, Pred=1
# 9- (60)_flipped_flipped_flipped.jpg: GT=9, Pred=3
# 9- (61).png: GT=9, Pred=4
# 9- (61)_flipped.jpg: GT=9, Pred=4
# 9- (61)_flipped_flipped.jpg: GT=9, Pred=4
# 9- (61)_flipped_flipped_flipped.jpg: GT=9, Pred=4
# 9- (62).png: GT=9, Pred=0
# 9- (62)_flipped.jpg: GT=9, Pred=3
# 9- (62)_flipped_flipped.jpg: GT=9, Pred=1
# 9- (62)_flipped_flipped_flipped.jpg: GT=9, Pred=3
# 9- (63).png: GT=9, Pred=1
# 9- (63)_flipped.jpg: GT=9, Pred=1
# 9- (63)_flipped_flipped.jpg: GT=9, Pred=3
# 9- (63)_flipped_flipped_flipped.jpg: GT=9, Pred=1
# 9- (64).png: GT=9, Pred=2
# 9- (64)_flipped.jpg: GT=9, Pred=2
# 9- (64)_flipped_flipped.jpg: GT=9, Pred=3
# 9- (64)_flipped_flipped_flipped.jpg: GT=9, Pred=2
# 9- (65).png: GT=9, Pred=3
# 9- (65)_flipped.jpg: GT=9, Pred=2
# 9- (65)_flipped_flipped.jpg: GT=9, Pred=4
# 9- (65)_flipped_flipped_flipped.jpg: GT=9, Pred=2
# 9- (66).png: GT=9, Pred=2
# 9- (66)_flipped.jpg: GT=9, Pred=4
# 9- (66)_flipped_flipped.jpg: GT=9, Pred=3
# 9- (66)_flipped_flipped_flipped.jpg: GT=9, Pred=4
# 9- (67).png: GT=9, Pred=1
# 9- (67)_flipped.jpg: GT=9, Pred=4
# 9- (67)_flipped_flipped.jpg: GT=9, Pred=3
# 9- (67)_flipped_flipped_flipped.jpg: GT=9, Pred=4
# 9- (68).png: GT=9, Pred=4
# 9- (68)_flipped.jpg: GT=9, Pred=4
# 9- (68)_flipped_flipped.jpg: GT=9, Pred=3
# 9- (68)_flipped_flipped_flipped.jpg: GT=9, Pred=4
# 9- (69).png: GT=9, Pred=0
# 9- (69)_flipped.jpg: GT=9, Pred=1
# 9- (69)_flipped_flipped.jpg: GT=9, Pred=3
# 9- (69)_flipped_flipped_flipped.jpg: GT=9, Pred=1
# 9- (7).png: GT=9, Pred=4
# 9- (7)_flipped.jpg: GT=9, Pred=5
# 9- (7)_flipped_flipped.jpg: GT=9, Pred=5
# 9- (7)_flipped_flipped_flipped.jpg: GT=9, Pred=5
# 9- (70).png: GT=9, Pred=1
# 9- (70)_flipped.jpg: GT=9, Pred=3
# 9- (70)_flipped_flipped.jpg: GT=9, Pred=1
# 9- (70)_flipped_flipped_flipped.jpg: GT=9, Pred=3
# 9- (71).png: GT=9, Pred=2
# 9- (71)_flipped.jpg: GT=9, Pred=4
# 9- (71)_flipped_flipped.jpg: GT=9, Pred=3
# 9- (71)_flipped_flipped_flipped.jpg: GT=9, Pred=4
# 9- (72).png: GT=9, Pred=2
# 9- (72)_flipped.jpg: GT=9, Pred=4
# 9- (72)_flipped_flipped.jpg: GT=9, Pred=3
# 9- (72)_flipped_flipped_flipped.jpg: GT=9, Pred=4
# 9- (73).png: GT=9, Pred=0
# 9- (73)_flipped.jpg: GT=9, Pred=2
# 9- (73)_flipped_flipped.jpg: GT=9, Pred=1
# 9- (73)_flipped_flipped_flipped.jpg: GT=9, Pred=2
# 9- (74).png: GT=9, Pred=1
# 9- (74)_flipped.jpg: GT=9, Pred=3
# 9- (74)_flipped_flipped.jpg: GT=9, Pred=3
# 9- (74)_flipped_flipped_flipped.jpg: GT=9, Pred=3
# 9- (75).png: GT=9, Pred=0
# 9- (75)_flipped.jpg: GT=9, Pred=3
# 9- (75)_flipped_flipped.jpg: GT=9, Pred=3
# 9- (75)_flipped_flipped_flipped.jpg: GT=9, Pred=3
# 9- (76).png: GT=9, Pred=1
# 9- (76)_flipped.jpg: GT=9, Pred=3
# 9- (76)_flipped_flipped.jpg: GT=9, Pred=3
# 9- (76)_flipped_flipped_flipped.jpg: GT=9, Pred=3
# 9- (8).png: GT=9, Pred=4
# 9- (8)_flipped.jpg: GT=9, Pred=4
# 9- (8)_flipped_flipped.jpg: GT=9, Pred=3
# 9- (8)_flipped_flipped_flipped.jpg: GT=9, Pred=4
# 9- (9).png: GT=9, Pred=2
# 9- (9)_flipped.jpg: GT=9, Pred=3
# 9- (9)_flipped_flipped.jpg: GT=9, Pred=4
# 9- (9)_flipped_flipped_flipped.jpg: GT=9, Pred=3

# %%
# --------------------------
# 📈 Overall Accuracy
# --------------------------

def calculate_abfa_accuracy(results, binary=True, threshold=1):
    """
    Calculate accuracy from results list.

    Args:
        results: list of (filename, ground_truth, predicted_count)
        binary: whether to binarize classification (e.g., count >= threshold is class 1)
        threshold: count threshold to decide positive class

    Returns:
        accuracy: float
        mismatches: list of (filename, ground_truth, predicted_count)
    """
    correct = 0
    mismatches = []

    for filename, gt, pred in results:
        pred_class = 1 if pred >= threshold else 0
        gt_class = 1 if gt >= 1 else 0 if binary else gt

        if pred_class == gt_class:
            correct += 1
        else:
            mismatches.append((filename, gt, pred))

    total = len(results)
    accuracy = correct / total if total > 0 else 0.0
    return accuracy, mismatches

# Call the function
accuracy, mismatches = calculate_abfa_accuracy(results)

# Print overall accuracy
print(f"\n📈 Overall Accuracy: {accuracy:.2%}")

# Optionally show mismatches
print("\n🔍 Mismatches:")
for filename, gt, pred in mismatches:
    print(f"{filename}: GT={gt}, Pred={pred}")
# Out:
# 📈 Overall Accuracy: 78.60%
#
# 🔍 Mismatches:
# 100.png: GT=1, Pred=0
# 104.png: GT=1, Pred=0
# 104_flipped_flipped.jpg: GT=1, Pred=0
# 34.png: GT=1, Pred=0
# 35.png: GT=1, Pred=0
# 35_flipped.jpg: GT=1, Pred=0
# 35_flipped_flipped.jpg: GT=1, Pred=0
# 35_flipped_flipped_flipped.jpg: GT=1, Pred=0
# 38_flipped.jpg: GT=1, Pred=0
# 38_flipped_flipped_flipped.jpg: GT=1, Pred=0
# 39_flipped.jpg: GT=1, Pred=0
# 39_flipped_flipped_flipped.jpg: GT=1, Pred=0
# 56_flipped.jpg: GT=1, Pred=0
# 58_flipped.jpg: GT=1, Pred=0
# 58_flipped_flipped_flipped.jpg: GT=1, Pred=0
# 60_flipped.jpg: GT=1, Pred=0
# 60_flipped_flipped_flipped.jpg: GT=1, Pred=0
# 71_flipped.jpg: GT=1, Pred=0
# 71_flipped_flipped.jpg: GT=1, Pred=0
# 71_flipped_flipped_flipped.jpg: GT=1, Pred=0
# 72.png: GT=1, Pred=0
# 72_flipped_flipped.jpg: GT=1, Pred=0
# 73.png: GT=1, Pred=0
# 73_flipped_flipped.jpg: GT=1, Pred=0
# 74_flipped.jpg: GT=1, Pred=0
# 74_flipped_flipped_flipped.jpg: GT=1, Pred=0
# 75.png: GT=1, Pred=0
# 75_flipped.jpg: GT=1, Pred=0
# 75_flipped_flipped.jpg: GT=1, Pred=0
# 75_flipped_flipped_flipped.jpg: GT=1, Pred=0
# 76.png: GT=1, Pred=0
# 76_flipped_flipped.jpg: GT=1, Pred=0
# 81.png: GT=1, Pred=0
# 81_flipped_flipped.jpg: GT=1, Pred=0
# 87.png: GT=1, Pred=0
# 87_flipped.jpg: GT=1, Pred=0
# 87_flipped_flipped.jpg: GT=1, Pred=0
# 87_flipped_flipped_flipped.jpg: GT=1, Pred=0
# 88_flipped_flipped_flipped.jpg: GT=1, Pred=0
# 91.png: GT=1, Pred=0
# 91_flipped_flipped.jpg: GT=1, Pred=0
# 92_flipped.jpg: GT=1, Pred=0
# 92_flipped_flipped_flipped.jpg: GT=1, Pred=0
# 95.png: GT=1, Pred=0
# 95_flipped_flipped.jpg: GT=1, Pred=0
# 10- (1)_flipped.jpg: GT=10, Pred=0
# 10- (1)_flipped_flipped_flipped.jpg: GT=10, Pred=0
# 10- (10).png: GT=10, Pred=0
# 10- (10)_flipped.jpg: GT=10, Pred=0
# 10- (10)_flipped_flipped.jpg: GT=10, Pred=0
# 10- (10)_flipped_flipped_flipped.jpg: GT=10, Pred=0
# 10- (11).png: GT=10, Pred=0
# 10- (11)_flipped.jpg: GT=10, Pred=0
# 10- (11)_flipped_flipped_flipped.jpg: GT=10, Pred=0
# 10- (12).png: GT=10, Pred=0
# 10- (12)_flipped.jpg: GT=10, Pred=0
# 10- (12)_flipped_flipped_flipped.jpg: GT=10, Pred=0
# 10- (13).png: GT=10, Pred=0
# 10- (13)_flipped.jpg: GT=10, Pred=0
# 10- (13)_flipped_flipped_flipped.jpg: GT=10, Pred=0
# 10- (14).png: GT=10, Pred=0
# 10- (14)_flipped.jpg: GT=10, Pred=0
# 10- (14)_flipped_flipped_flipped.jpg: GT=10, Pred=0
# 10- (15).png: GT=10, Pred=0
# 10- (15)_flipped.jpg: GT=10, Pred=0
# 10- (15)_flipped_flipped.jpg: GT=10, Pred=0
# 10- (15)_flipped_flipped_flipped.jpg: GT=10, Pred=0
# 10- (16).png: GT=10, Pred=0
# 10- (16)_flipped.jpg: GT=10, Pred=0
# 10- (16)_flipped_flipped.jpg: GT=10, Pred=0
# 10- (16)_flipped_flipped_flipped.jpg: GT=10, Pred=0
# 10- (17).png: GT=10, Pred=0
# 10- (17)_flipped.jpg: GT=10, Pred=0
# 10- (17)_flipped_flipped_flipped.jpg: GT=10, Pred=0
# 10- (18).png: GT=10, Pred=0
# 10- (18)_flipped.jpg: GT=10, Pred=0
# 10- (18)_flipped_flipped_flipped.jpg: GT=10, Pred=0
# 10- (19).png: GT=10, Pred=0
# 10- (19)_flipped.jpg: GT=10, Pred=0
# 10- (19)_flipped_flipped_flipped.jpg: GT=10, Pred=0
# 10- (2).png: GT=10, Pred=0
# 10- (2)_flipped.jpg: GT=10, Pred=0
# 10- (2)_flipped_flipped_flipped.jpg: GT=10, Pred=0
# 10- (20)_flipped.jpg: GT=10, Pred=0
# 10- (20)_flipped_flipped_flipped.jpg: GT=10, Pred=0
# 10- (3).png: GT=10, Pred=0
# 10- (3)_flipped.jpg: GT=10, Pred=0
# 10- (3)_flipped_flipped.jpg: GT=10, Pred=0
# 10- (3)_flipped_flipped_flipped.jpg: GT=10, Pred=0
# 10- (34)_flipped.jpg: GT=10, Pred=0
# 10- (34)_flipped_flipped_flipped.jpg: GT=10, Pred=0
# 10- (4)_flipped.jpg: GT=10, Pred=0
# 10- (4)_flipped_flipped_flipped.jpg: GT=10, Pred=0
# 10- (43)_flipped.jpg: GT=10, Pred=0
# 10- (43)_flipped_flipped_flipped.jpg: GT=10, Pred=0
# 10- (5).png: GT=10, Pred=0
# 10- (5)_flipped.jpg: GT=10, Pred=0
# 10- (5)_flipped_flipped_flipped.jpg: GT=10, Pred=0
# 10- (52).png: GT=10, Pred=0
# 10- (52)_flipped.jpg: GT=10, Pred=0
# 10- (52)_flipped_flipped_flipped.jpg: GT=10, Pred=0
# 10- (6)_flipped.jpg: GT=10, Pred=0
# 10- (6)_flipped_flipped_flipped.jpg: GT=10, Pred=0
# 10- (7)_flipped.jpg: GT=10, Pred=0
# 10- (7)_flipped_flipped_flipped.jpg: GT=10, Pred=0
# 10- (8).png: GT=10, Pred=0
# 10- (8)_flipped.jpg: GT=10, Pred=0
# 10- (8)_flipped_flipped.jpg: GT=10, Pred=0
# 10- (8)_flipped_flipped_flipped.jpg: GT=10, Pred=0
# 10- (9).png: GT=10, Pred=0
# 10- (9)_flipped.jpg: GT=10, Pred=0
# 10- (9)_flipped_flipped_flipped.jpg: GT=10, Pred=0
# 11- (1).png: GT=11, Pred=0
# 11- (1)_flipped.jpg: GT=11, Pred=0
# 11- (1)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (1)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (11).png: GT=11, Pred=0
# 11- (12).png: GT=11, Pred=0
# 11- (16)_flipped.jpg: GT=11, Pred=0
# 11- (16)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (17).png: GT=11, Pred=0
# 11- (18).png: GT=11, Pred=0
# 11- (20).png: GT=11, Pred=0
# 11- (22).png: GT=11, Pred=0
# 11- (26).png: GT=11, Pred=0
# 11- (28).png: GT=11, Pred=0
# 11- (3).png: GT=11, Pred=0
# 11- (31).png: GT=11, Pred=0
# 11- (31)_flipped.jpg: GT=11, Pred=0
# 11- (31)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (31)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (33).png: GT=11, Pred=0
# 11- (33)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (34)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (35).png: GT=11, Pred=0
# 11- (37)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (39)_flipped.jpg: GT=11, Pred=0
# 11- (39)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (39)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (4).png: GT=11, Pred=0
# 11- (40).png: GT=11, Pred=0
# 11- (40)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (41)_flipped.jpg: GT=11, Pred=0
# 11- (41)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (41)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (42)_flipped.jpg: GT=11, Pred=0
# 11- (42)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (42)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (43)_flipped.jpg: GT=11, Pred=0
# 11- (43)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (43)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (44).png: GT=11, Pred=0
# 11- (44)_flipped.jpg: GT=11, Pred=0
# 11- (44)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (44)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (45).png: GT=11, Pred=0
# 11- (45)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (46).png: GT=11, Pred=0
# 11- (48).png: GT=11, Pred=0
# 11- (49).png: GT=11, Pred=0
# 11- (51).png: GT=11, Pred=0
# 11- (53).png: GT=11, Pred=0
# 11- (54).png: GT=11, Pred=0
# 11- (54)_flipped.jpg: GT=11, Pred=0
# 11- (54)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (54)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (55)_flipped.jpg: GT=11, Pred=0
# 11- (55)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (55)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (56).png: GT=11, Pred=0
# 11- (56)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (57)_flipped.jpg: GT=11, Pred=0
# 11- (57)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (58).png: GT=11, Pred=0
# 11- (58)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (6).png: GT=11, Pred=0
# 11- (60).png: GT=11, Pred=0
# 11- (60)_flipped.jpg: GT=11, Pred=0
# 11- (60)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (60)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (62).png: GT=11, Pred=0
# 11- (63).png: GT=11, Pred=0
# 11- (63)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (64)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (65)_flipped.jpg: GT=11, Pred=0
# 11- (65)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (66)_flipped.jpg: GT=11, Pred=0
# 11- (66)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (66)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (67)_flipped.jpg: GT=11, Pred=0
# 11- (67)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (68).png: GT=11, Pred=0
# 11- (68)_flipped.jpg: GT=11, Pred=0
# 11- (68)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (68)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (69).png: GT=11, Pred=0
# 11- (70)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (71).png: GT=11, Pred=0
# 11- (71)_flipped.jpg: GT=11, Pred=0
# 11- (71)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (72)_flipped.jpg: GT=11, Pred=0
# 11- (72)_flipped_flipped.jpg: GT=11, Pred=0
# 11- (72)_flipped_flipped_flipped.jpg: GT=11, Pred=0
# 11- (8).png: GT=11, Pred=0
# 12- (15)_flipped.jpg: GT=12, Pred=0
# 12- (15)_flipped_flipped_flipped.jpg: GT=12, Pred=0
# 12- (16)_flipped.jpg: GT=12, Pred=0
# 12- (16)_flipped_flipped_flipped.jpg: GT=12, Pred=0
# 12- (17)_flipped.jpg: GT=12, Pred=0
# 12- (17)_flipped_flipped_flipped.jpg: GT=12, Pred=0
# 12- (18)_flipped.jpg: GT=12, Pred=0
# 12- (18)_flipped_flipped_flipped.jpg: GT=12, Pred=0
# 12- (19)_flipped.jpg: GT=12, Pred=0
# 12- (19)_flipped_flipped_flipped.jpg: GT=12, Pred=0
# 12- (20)_flipped.jpg: GT=12, Pred=0
# 12- (20)_flipped_flipped_flipped.jpg: GT=12, Pred=0
# 12- (21)_flipped.jpg: GT=12, Pred=0
# 12- (21)_flipped_flipped_flipped.jpg: GT=12, Pred=0
# 12- (22)_flipped.jpg: GT=12, Pred=0
# 12- (22)_flipped_flipped_flipped.jpg: GT=12, Pred=0
# 12- (23)_flipped.jpg: GT=12, Pred=0
# 12- (23)_flipped_flipped_flipped.jpg: GT=12, Pred=0
# 12- (24)_flipped.jpg: GT=12, Pred=0
# 12- (24)_flipped_flipped_flipped.jpg: GT=12, Pred=0
# 12- (25)_flipped.jpg: GT=12, Pred=0
# 12- (25)_flipped_flipped_flipped.jpg: GT=12, Pred=0
# 12- (26)_flipped.jpg: GT=12, Pred=0
# 12- (26)_flipped_flipped_flipped.jpg: GT=12, Pred=0
# 12- (27)_flipped_flipped.jpg: GT=12, Pred=0
# 12- (28)_flipped.jpg: GT=12, Pred=0
# 12- (28)_flipped_flipped_flipped.jpg: GT=12, Pred=0
# 12- (29)_flipped.jpg: GT=12, Pred=0
# 12- (29)_flipped_flipped_flipped.jpg: GT=12, Pred=0
# 12- (30)_flipped.jpg: GT=12, Pred=0
# 12- (30)_flipped_flipped_flipped.jpg: GT=12, Pred=0
# 12- (31)_flipped.jpg: GT=12, Pred=0
# 12- (31)_flipped_flipped_flipped.jpg: GT=12, Pred=0
# 12- (32)_flipped.jpg: GT=12, Pred=0
# 12- (32)_flipped_flipped_flipped.jpg: GT=12, Pred=0
# 12- (33)_flipped.jpg: GT=12, Pred=0
# 12- (33)_flipped_flipped_flipped.jpg: GT=12, Pred=0
# 12- (34)_flipped.jpg: GT=12, Pred=0
# 12- (34)_flipped_flipped_flipped.jpg: GT=12, Pred=0
# 12- (35)_flipped.jpg: GT=12, Pred=0
# 12- (35)_flipped_flipped_flipped.jpg: GT=12, Pred=0
# 12- (36)_flipped.jpg: GT=12, Pred=0
# 12- (36)_flipped_flipped_flipped.jpg: GT=12, Pred=0
# 12- (37).png: GT=12, Pred=0
# 12- (37)_flipped.jpg: GT=12, Pred=0
# 12- (37)_flipped_flipped_flipped.jpg: GT=12, Pred=0
# 12- (38)_flipped.jpg: GT=12, Pred=0
# 12- (38)_flipped_flipped_flipped.jpg: GT=12, Pred=0
# 12- (39).png: GT=12, Pred=0
# 12- (39)_flipped.jpg: GT=12, Pred=0
# 12- (39)_flipped_flipped_flipped.jpg: GT=12, Pred=0
# 12- (4)_flipped.jpg: GT=12, Pred=0
# 12- (4)_flipped_flipped_flipped.jpg: GT=12, Pred=0
# 12- (40).png: GT=12, Pred=0
# 12- (40)_flipped.jpg: GT=12, Pred=0
# 12- (40)_flipped_flipped_flipped.jpg: GT=12, Pred=0
# 12- (47)_flipped.jpg: GT=12, Pred=0
# 12- (47)_flipped_flipped_flipped.jpg: GT=12, Pred=0
# 12- (49).png: GT=12, Pred=0
# 12- (52).png: GT=12, Pred=0
# 13- (1)_flipped.jpg: GT=13, Pred=0
# 13- (1)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (10)_flipped.jpg: GT=13, Pred=0
# 13- (10)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (11)_flipped.jpg: GT=13, Pred=0
# 13- (11)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (12)_flipped.jpg: GT=13, Pred=0
# 13- (12)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (13)_flipped.jpg: GT=13, Pred=0
# 13- (13)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (14)_flipped.jpg: GT=13, Pred=0
# 13- (14)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (15)_flipped.jpg: GT=13, Pred=0
# 13- (15)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (16)_flipped.jpg: GT=13, Pred=0
# 13- (16)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (17)_flipped.jpg: GT=13, Pred=0
# 13- (17)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (18)_flipped.jpg: GT=13, Pred=0
# 13- (18)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (19)_flipped.jpg: GT=13, Pred=0
# 13- (19)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (2)_flipped.jpg: GT=13, Pred=0
# 13- (2)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (20)_flipped.jpg: GT=13, Pred=0
# 13- (20)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (21)_flipped.jpg: GT=13, Pred=0
# 13- (21)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (22)_flipped.jpg: GT=13, Pred=0
# 13- (22)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (23)_flipped.jpg: GT=13, Pred=0
# 13- (23)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (24)_flipped.jpg: GT=13, Pred=0
# 13- (24)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (25)_flipped.jpg: GT=13, Pred=0
# 13- (25)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (26)_flipped.jpg: GT=13, Pred=0
# 13- (26)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (27)_flipped.jpg: GT=13, Pred=0
# 13- (27)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (28)_flipped.jpg: GT=13, Pred=0
# 13- (28)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (29)_flipped.jpg: GT=13, Pred=0
# 13- (29)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (3)_flipped.jpg: GT=13, Pred=0
# 13- (3)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (34).png: GT=13, Pred=0
# 13- (36).png: GT=13, Pred=0
# 13- (37).png: GT=13, Pred=0
# 13- (38).png: GT=13, Pred=0
# 13- (4)_flipped.jpg: GT=13, Pred=0
# 13- (4)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (42).png: GT=13, Pred=0
# 13- (43).png: GT=13, Pred=0
# 13- (43)_flipped_flipped.jpg: GT=13, Pred=0
# 13- (44).png: GT=13, Pred=0
# 13- (48).png: GT=13, Pred=0
# 13- (5)_flipped.jpg: GT=13, Pred=0
# 13- (5)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (6)_flipped.jpg: GT=13, Pred=0
# 13- (6)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (7)_flipped.jpg: GT=13, Pred=0
# 13- (7)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (8)_flipped.jpg: GT=13, Pred=0
# 13- (8)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 13- (9)_flipped.jpg: GT=13, Pred=0
# 13- (9)_flipped_flipped_flipped.jpg: GT=13, Pred=0
# 14- (1).png: GT=14, Pred=0
# 14- (1)_flipped_flipped.jpg: GT=14, Pred=0
# 14- (10).png: GT=14, Pred=0
# 14- (10)_flipped.jpg: GT=14, Pred=0
# 14- (10)_flipped_flipped.jpg: GT=14, Pred=0
# 14- (10)_flipped_flipped_flipped.jpg: GT=14, Pred=0
# 14- (11).png: GT=14, Pred=0
# 14- (11)_flipped_flipped.jpg: GT=14, Pred=0
# 14- (12).png: GT=14, Pred=0
# 14- (12)_flipped.jpg: GT=14, Pred=0
# 14- (12)_flipped_flipped.jpg: GT=14, Pred=0
# 14- (12)_flipped_flipped_flipped.jpg: GT=14, Pred=0
# 14- (13).png: GT=14, Pred=0
# 14- (13)_flipped_flipped.jpg: GT=14, Pred=0
# 14- (14).png: GT=14, Pred=0
# 14- (14)_flipped.jpg: GT=14, Pred=0
# 14- (14)_flipped_flipped.jpg: GT=14, Pred=0
# 14- (14)_flipped_flipped_flipped.jpg: GT=14, Pred=0
# 14- (15).png: GT=14, Pred=0
# 14- (15)_flipped.jpg: GT=14, Pred=0
# 14- (15)_flipped_flipped.jpg: GT=14, Pred=0
# 14- (15)_flipped_flipped_flipped.jpg: GT=14, Pred=0
# 14- (16)_flipped_flipped.jpg: GT=14, Pred=0
# 14- (17).png: GT=14, Pred=0
# 14- (17)_flipped.jpg: GT=14, Pred=0
# 14- (17)_flipped_flipped.jpg: GT=14, Pred=0
# 14- (17)_flipped_flipped_flipped.jpg: GT=14, Pred=0
# 14- (18).png: GT=14, Pred=0
# 14- (2).png: GT=14, Pred=0
# 14- (2)_flipped.jpg: GT=14, Pred=0
# 14- (2)_flipped_flipped.jpg: GT=14, Pred=0
# 14- (2)_flipped_flipped_flipped.jpg: GT=14, Pred=0
# 14- (20)_flipped.jpg: GT=14, Pred=0
# 14- (20)_flipped_flipped.jpg: GT=14, Pred=0
# 14- (20)_flipped_flipped_flipped.jpg: GT=14, Pred=0
# 14- (21).png: GT=14, Pred=0
# 14- (21)_flipped.jpg: GT=14, Pred=0
# 14- (21)_flipped_flipped.jpg: GT=14, Pred=0
# 14- (21)_flipped_flipped_flipped.jpg: GT=14, Pred=0
# 14- (22)_flipped_flipped.jpg: GT=14, Pred=0
# 14- (23).png: GT=14, Pred=0
# 14- (23)_flipped_flipped.jpg: GT=14, Pred=0
# 14- (28)_flipped.jpg: GT=14, Pred=0
# 14- (28)_flipped_flipped.jpg: GT=14, Pred=0
# 14- (28)_flipped_flipped_flipped.jpg: GT=14, Pred=0
# 14- (3).png: GT=14, Pred=0
# 14- (3)_flipped_flipped.jpg: GT=14, Pred=0
# 14- (30).png: GT=14, Pred=0
# 14- (32)_flipped.jpg: GT=14, Pred=0
# 14- (32)_flipped_flipped.jpg: GT=14, Pred=0
# 14- (32)_flipped_flipped_flipped.jpg: GT=14, Pred=0
# 14- (33).png: GT=14, Pred=0
# 14- (34)_flipped.jpg: GT=14, Pred=0
# 14- (34)_flipped_flipped.jpg: GT=14, Pred=0
# 14- (34)_flipped_flipped_flipped.jpg: GT=14, Pred=0
# 14- (39)_flipped.jpg: GT=14, Pred=0
# 14- (39)_flipped_flipped_flipped.jpg: GT=14, Pred=0
# 14- (4).png: GT=14, Pred=0
# 14- (4)_flipped.jpg: GT=14, Pred=0
# 14- (4)_flipped_flipped.jpg: GT=14, Pred=0
# 14- (4)_flipped_flipped_flipped.jpg: GT=14, Pred=0
# 14- (44).png: GT=14, Pred=0
# 14- (5)_flipped_flipped.jpg: GT=14, Pred=0
# 14- (6).png: GT=14, Pred=0
# 14- (6)_flipped_flipped.jpg: GT=14, Pred=0
# 14- (7).png: GT=14, Pred=0
# 14- (7)_flipped_flipped.jpg: GT=14, Pred=0
# 14- (8)_flipped_flipped.jpg: GT=14, Pred=0
# 14- (9)_flipped_flipped.jpg: GT=14, Pred=0
# 15- (1).png: GT=15, Pred=0
# 15- (1)_flipped.jpg: GT=15, Pred=0
# 15- (1)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (1)_flipped_flipped_flipped.jpg: GT=15, Pred=0
# 15- (10)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (11).png: GT=15, Pred=0
# 15- (11)_flipped.jpg: GT=15, Pred=0
# 15- (11)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (11)_flipped_flipped_flipped.jpg: GT=15, Pred=0
# 15- (12).png: GT=15, Pred=0
# 15- (12)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (13).png: GT=15, Pred=0
# 15- (13)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (14).png: GT=15, Pred=0
# 15- (14)_flipped.jpg: GT=15, Pred=0
# 15- (14)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (14)_flipped_flipped_flipped.jpg: GT=15, Pred=0
# 15- (15).png: GT=15, Pred=0
# 15- (15)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (16).png: GT=15, Pred=0
# 15- (16)_flipped.jpg: GT=15, Pred=0
# 15- (16)_flipped_flipped_flipped.jpg: GT=15, Pred=0
# 15- (17).png: GT=15, Pred=0
# 15- (17)_flipped.jpg: GT=15, Pred=0
# 15- (17)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (17)_flipped_flipped_flipped.jpg: GT=15, Pred=0
# 15- (18).png: GT=15, Pred=0
# 15- (18)_flipped.jpg: GT=15, Pred=0
# 15- (18)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (18)_flipped_flipped_flipped.jpg: GT=15, Pred=0
# 15- (19).png: GT=15, Pred=0
# 15- (19)_flipped.jpg: GT=15, Pred=0
# 15- (19)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (19)_flipped_flipped_flipped.jpg: GT=15, Pred=0
# 15- (2).png: GT=15, Pred=0
# 15- (2)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (20).png: GT=15, Pred=0
# 15- (20)_flipped.jpg: GT=15, Pred=0
# 15- (20)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (20)_flipped_flipped_flipped.jpg: GT=15, Pred=0
# 15- (21).png: GT=15, Pred=0
# 15- (21)_flipped.jpg: GT=15, Pred=0
# 15- (21)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (21)_flipped_flipped_flipped.jpg: GT=15, Pred=0
# 15- (22).png: GT=15, Pred=0
# 15- (22)_flipped.jpg: GT=15, Pred=0
# 15- (22)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (22)_flipped_flipped_flipped.jpg: GT=15, Pred=0
# 15- (23).png: GT=15, Pred=0
# 15- (23)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (24).png: GT=15, Pred=0
# 15- (24)_flipped.jpg: GT=15, Pred=0
# 15- (24)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (24)_flipped_flipped_flipped.jpg: GT=15, Pred=0
# 15- (25).png: GT=15, Pred=0
# 15- (25)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (26).png: GT=15, Pred=0
# 15- (26)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (27).png: GT=15, Pred=0
# 15- (27)_flipped.jpg: GT=15, Pred=0
# 15- (27)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (27)_flipped_flipped_flipped.jpg: GT=15, Pred=0
# 15- (28).png: GT=15, Pred=0
# 15- (28)_flipped.jpg: GT=15, Pred=0
# 15- (28)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (28)_flipped_flipped_flipped.jpg: GT=15, Pred=0
# 15- (29).png: GT=15, Pred=0
# 15- (29)_flipped.jpg: GT=15, Pred=0
# 15- (29)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (29)_flipped_flipped_flipped.jpg: GT=15, Pred=0
# 15- (3)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (30)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (31).png: GT=15, Pred=0
# 15- (31)_flipped.jpg: GT=15, Pred=0
# 15- (31)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (31)_flipped_flipped_flipped.jpg: GT=15, Pred=0
# 15- (32).png: GT=15, Pred=0
# 15- (32)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (33).png: GT=15, Pred=0
# 15- (33)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (34).png: GT=15, Pred=0
# 15- (34)_flipped.jpg: GT=15, Pred=0
# 15- (34)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (34)_flipped_flipped_flipped.jpg: GT=15, Pred=0
# 15- (35).png: GT=15, Pred=0
# 15- (35)_flipped.jpg: GT=15, Pred=0
# 15- (35)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (35)_flipped_flipped_flipped.jpg: GT=15, Pred=0
# 15- (36).png: GT=15, Pred=0
# 15- (36)_flipped.jpg: GT=15, Pred=0
# 15- (36)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (36)_flipped_flipped_flipped.jpg: GT=15, Pred=0
# 15- (37).png: GT=15, Pred=0
# 15- (38).png: GT=15, Pred=0
# 15- (38)_flipped.jpg: GT=15, Pred=0
# 15- (38)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (38)_flipped_flipped_flipped.jpg: GT=15, Pred=0
# 15- (39).png: GT=15, Pred=0
# 15- (4).png: GT=15, Pred=0
# 15- (4)_flipped.jpg: GT=15, Pred=0
# 15- (4)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (4)_flipped_flipped_flipped.jpg: GT=15, Pred=0
# 15- (40).png: GT=15, Pred=0
# 15- (40)_flipped.jpg: GT=15, Pred=0
# 15- (40)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (40)_flipped_flipped_flipped.jpg: GT=15, Pred=0
# 15- (41).png: GT=15, Pred=0
# 15- (42).png: GT=15, Pred=0
# 15- (43)_flipped.jpg: GT=15, Pred=0
# 15- (43)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (43)_flipped_flipped_flipped.jpg: GT=15, Pred=0
# 15- (47).png: GT=15, Pred=0
# 15- (49).png: GT=15, Pred=0
# 15- (5).png: GT=15, Pred=0
# 15- (5)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (50).png: GT=15, Pred=0
# 15- (52).png: GT=15, Pred=0
# 15- (54).png: GT=15, Pred=0
# 15- (55).png: GT=15, Pred=0
# 15- (56).png: GT=15, Pred=0
# 15- (57).png: GT=15, Pred=0
# 15- (59).png: GT=15, Pred=0
# 15- (6).png: GT=15, Pred=0
# 15- (6)_flipped.jpg: GT=15, Pred=0
# 15- (6)_flipped_flipped_flipped.jpg: GT=15, Pred=0
# 15- (60).png: GT=15, Pred=0
# 15- (61).png: GT=15, Pred=0
# 15- (62)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (63)_flipped.jpg: GT=15, Pred=0
# 15- (63)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (63)_flipped_flipped_flipped.jpg: GT=15, Pred=0
# 15- (64).png: GT=15, Pred=0
# 15- (64)_flipped.jpg: GT=15, Pred=0
# 15- (64)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (64)_flipped_flipped_flipped.jpg: GT=15, Pred=0
# 15- (7).png: GT=15, Pred=0
# 15- (7)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (8).png: GT=15, Pred=0
# 15- (8)_flipped.jpg: GT=15, Pred=0
# 15- (8)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (8)_flipped_flipped_flipped.jpg: GT=15, Pred=0
# 15- (9)_flipped.jpg: GT=15, Pred=0
# 15- (9)_flipped_flipped.jpg: GT=15, Pred=0
# 15- (9)_flipped_flipped_flipped.jpg: GT=15, Pred=0
# 31.png: GT=2, Pred=0
# 31_flipped.jpg: GT=2, Pred=0
# 31_flipped_flipped.jpg: GT=2, Pred=0
# 31_flipped_flipped_flipped.jpg: GT=2, Pred=0
# 34.png: GT=2, Pred=0
# 34_flipped.jpg: GT=2, Pred=0
# 34_flipped_flipped.jpg: GT=2, Pred=0
# 34_flipped_flipped_flipped.jpg: GT=2, Pred=0
# 53.png: GT=2, Pred=0
# 53_flipped.jpg: GT=2, Pred=0
# 53_flipped_flipped.jpg: GT=2, Pred=0
# 53_flipped_flipped_flipped.jpg: GT=2, Pred=0
# 76.png: GT=2, Pred=0
# 76_flipped.jpg: GT=2, Pred=0
# 76_flipped_flipped.jpg: GT=2, Pred=0
# 76_flipped_flipped_flipped.jpg: GT=2, Pred=0
# 17.png: GT=3, Pred=0
# 17_flipped.jpg: GT=3, Pred=0
# 17_flipped_flipped.jpg: GT=3, Pred=0
# 17_flipped_flipped_flipped.jpg: GT=3, Pred=0
# 40.png: GT=3, Pred=0
# 40_flipped.jpg: GT=3, Pred=0
# 40_flipped_flipped.jpg: GT=3, Pred=0
# 40_flipped_flipped_flipped.jpg: GT=3, Pred=0
# 41.png: GT=3, Pred=0
# 41_flipped.jpg: GT=3, Pred=0
# 41_flipped_flipped.jpg: GT=3, Pred=0
# 41_flipped_flipped_flipped.jpg: GT=3, Pred=0
# 45.png: GT=3, Pred=0
# 45_flipped.jpg: GT=3, Pred=0
# 45_flipped_flipped.jpg: GT=3, Pred=0
# 45_flipped_flipped_flipped.jpg: GT=3, Pred=0
# 29.png: GT=4, Pred=0
# 29_flipped_flipped.jpg: GT=4, Pred=0
# 29_flipped_flipped_flipped.jpg: GT=4, Pred=0
# 5- (1)_flipped.jpg: GT=5, Pred=0
# 5- (1)_flipped_flipped.jpg: GT=5, Pred=0
# 5- (1)_flipped_flipped_flipped.jpg: GT=5, Pred=0
# 5- (19).png: GT=5, Pred=0
# 5- (19)_flipped.jpg: GT=5, Pred=0
# 5- (19)_flipped_flipped_flipped.jpg: GT=5, Pred=0
# 5- (23)_flipped.jpg: GT=5, Pred=0
# 5- (23)_flipped_flipped_flipped.jpg: GT=5, Pred=0
# 5- (25).png: GT=5, Pred=0
# 5- (26).png: GT=5, Pred=0
# 5- (26)_flipped.jpg: GT=5, Pred=0
# 5- (26)_flipped_flipped_flipped.jpg: GT=5, Pred=0
# 5- (3)_flipped.jpg: GT=5, Pred=0
# 5- (3)_flipped_flipped_flipped.jpg: GT=5, Pred=0
# 5- (4)_flipped.jpg: GT=5, Pred=0
# 5- (4)_flipped_flipped_flipped.jpg: GT=5, Pred=0
# 5- (40)_flipped.jpg: GT=5, Pred=0
# 5- (40)_flipped_flipped_flipped.jpg: GT=5, Pred=0
# 5- (5)_flipped.jpg: GT=5, Pred=0
# 5- (5)_flipped_flipped.jpg: GT=5, Pred=0
# 5- (5)_flipped_flipped_flipped.jpg: GT=5, Pred=0
# 5- (51).png: GT=5, Pred=0
# 5- (51)_flipped.jpg: GT=5, Pred=0
# 5- (51)_flipped_flipped_flipped.jpg: GT=5, Pred=0
# 5- (6).png: GT=5, Pred=0
# 5- (6)_flipped.jpg: GT=5, Pred=0
# 5- (6)_flipped_flipped.jpg: GT=5, Pred=0
# 5- (6)_flipped_flipped_flipped.jpg: GT=5, Pred=0
# 5- (7)_flipped.jpg: GT=5, Pred=0
# 5- (7)_flipped_flipped_flipped.jpg: GT=5, Pred=0
# 5- (8).png: GT=5, Pred=0
# 5- (8)_flipped.jpg: GT=5, Pred=0
# 5- (8)_flipped_flipped.jpg: GT=5, Pred=0
# 5- (8)_flipped_flipped_flipped.jpg: GT=5, Pred=0
# 5- (9)_flipped.jpg: GT=5, Pred=0
# 5- (9)_flipped_flipped_flipped.jpg: GT=5, Pred=0
# 6- (1)_flipped.jpg: GT=6, Pred=0
# 6- (1)_flipped_flipped.jpg: GT=6, Pred=0
# 6- (1)_flipped_flipped_flipped.jpg: GT=6, Pred=0
# 6- (10).png: GT=6, Pred=0
# 6- (13)_flipped.jpg: GT=6, Pred=0
# 6- (13)_flipped_flipped_flipped.jpg: GT=6, Pred=0
# 6- (14)_flipped.jpg: GT=6, Pred=0
# 6- (14)_flipped_flipped_flipped.jpg: GT=6, Pred=0
# 6- (15)_flipped.jpg: GT=6, Pred=0
# 6- (15)_flipped_flipped.jpg: GT=6, Pred=0
# 6- (15)_flipped_flipped_flipped.jpg: GT=6, Pred=0
# 6- (17)_flipped.jpg: GT=6, Pred=0
# 6- (17)_flipped_flipped_flipped.jpg: GT=6, Pred=0
# 6- (19).png: GT=6, Pred=0
# 6- (20)_flipped.jpg: GT=6, Pred=0
# 6- (20)_flipped_flipped.jpg: GT=6, Pred=0
# 6- (20)_flipped_flipped_flipped.jpg: GT=6, Pred=0
# 6- (21).png: GT=6, Pred=0
# 6- (3).png: GT=6, Pred=0
# 6- (35).png: GT=6, Pred=0
# 6- (36).png: GT=6, Pred=0
# 6- (36)_flipped.jpg: GT=6, Pred=0
# 6- (36)_flipped_flipped_flipped.jpg: GT=6, Pred=0
# 6- (4).png: GT=6, Pred=0
# 6- (9).png: GT=6, Pred=0
# 7- (1).png: GT=7, Pred=0
# 7- (1)_flipped_flipped.jpg: GT=7, Pred=0
# 7- (10).png: GT=7, Pred=0
# 7- (10)_flipped.jpg: GT=7, Pred=0
# 7- (10)_flipped_flipped_flipped.jpg: GT=7, Pred=0
# 7- (11).png: GT=7, Pred=0
# 7- (12)_flipped_flipped.jpg: GT=7, Pred=0
# 7- (14).png: GT=7, Pred=0
# 7- (15).png: GT=7, Pred=0
# 7- (17)_flipped_flipped.jpg: GT=7, Pred=0
# 7- (18).png: GT=7, Pred=0
# 7- (2)_flipped_flipped.jpg: GT=7, Pred=0
# 7- (20).png: GT=7, Pred=0
# 7- (23).png: GT=7, Pred=0
# 7- (23)_flipped_flipped.jpg: GT=7, Pred=0
# 7- (25)_flipped_flipped.jpg: GT=7, Pred=0
# 7- (27)_flipped_flipped.jpg: GT=7, Pred=0
# 7- (28).png: GT=7, Pred=0
# 7- (3).png: GT=7, Pred=0
# 7- (3)_flipped_flipped.jpg: GT=7, Pred=0
# 7- (31).png: GT=7, Pred=0
# 7- (34)_flipped_flipped.jpg: GT=7, Pred=0
# 7- (36).png: GT=7, Pred=0
# 7- (36)_flipped_flipped.jpg: GT=7, Pred=0
# 7- (37).png: GT=7, Pred=0
# 7- (37)_flipped_flipped.jpg: GT=7, Pred=0
# 7- (38).png: GT=7, Pred=0
# 7- (4).png: GT=7, Pred=0
# 7- (4)_flipped_flipped.jpg: GT=7, Pred=0
# 7- (40)_flipped_flipped.jpg: GT=7, Pred=0
# 7- (41).png: GT=7, Pred=0
# 7- (43).png: GT=7, Pred=0
# 7- (44).png: GT=7, Pred=0
# 7- (45).png: GT=7, Pred=0
# 7- (45)_flipped_flipped.jpg: GT=7, Pred=0
# 7- (46).png: GT=7, Pred=0
# 7- (46)_flipped_flipped.jpg: GT=7, Pred=0
# 7- (49).png: GT=7, Pred=0
# 7- (5)_flipped_flipped.jpg: GT=7, Pred=0
# 7- (51).png: GT=7, Pred=0
# 7- (51)_flipped_flipped.jpg: GT=7, Pred=0
# 7- (52)_flipped.jpg: GT=7, Pred=0
# 7- (52)_flipped_flipped.jpg: GT=7, Pred=0
# 7- (52)_flipped_flipped_flipped.jpg: GT=7, Pred=0
# 7- (53).png: GT=7, Pred=0
# 7- (53)_flipped_flipped.jpg: GT=7, Pred=0
# 7- (56).png: GT=7, Pred=0
# 7- (56)_flipped_flipped.jpg: GT=7, Pred=0
# 7- (6).png: GT=7, Pred=0
# 7- (6)_flipped_flipped.jpg: GT=7, Pred=0
# 7- (63).png: GT=7, Pred=0
# 7- (63)_flipped_flipped.jpg: GT=7, Pred=0
# 7- (64).png: GT=7, Pred=0
# 7- (64)_flipped_flipped.jpg: GT=7, Pred=0
# 7- (65)_flipped.jpg: GT=7, Pred=0
# 7- (65)_flipped_flipped.jpg: GT=7, Pred=0
# 7- (65)_flipped_flipped_flipped.jpg: GT=7, Pred=0
# 7- (66)_flipped_flipped.jpg: GT=7, Pred=0
# 7- (67).png: GT=7, Pred=0
# 7- (67)_flipped_flipped.jpg: GT=7, Pred=0
# 7- (69)_flipped_flipped.jpg: GT=7, Pred=0
# 7- (7).png: GT=7, Pred=0
# 7- (7)_flipped_flipped.jpg: GT=7, Pred=0
# 7- (70).png: GT=7, Pred=0
# 7- (71).png: GT=7, Pred=0
# 7- (71)_flipped_flipped.jpg: GT=7, Pred=0
# 7- (72)_flipped_flipped.jpg: GT=7, Pred=0
# 8- (11)_flipped_flipped.jpg: GT=8, Pred=0
# 8- (21)_flipped.jpg: GT=8, Pred=0
# 8- (21)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (25)_flipped.jpg: GT=8, Pred=0
# 8- (25)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (26)_flipped.jpg: GT=8, Pred=0
# 8- (26)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (27)_flipped.jpg: GT=8, Pred=0
# 8- (27)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (28).png: GT=8, Pred=0
# 8- (28)_flipped.jpg: GT=8, Pred=0
# 8- (28)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (32)_flipped.jpg: GT=8, Pred=0
# 8- (32)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (33)_flipped.jpg: GT=8, Pred=0
# 8- (33)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (35).png: GT=8, Pred=0
# 8- (35)_flipped.jpg: GT=8, Pred=0
# 8- (35)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (36)_flipped.jpg: GT=8, Pred=0
# 8- (36)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (37)_flipped.jpg: GT=8, Pred=0
# 8- (37)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (38)_flipped.jpg: GT=8, Pred=0
# 8- (38)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (39)_flipped.jpg: GT=8, Pred=0
# 8- (39)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (40)_flipped.jpg: GT=8, Pred=0
# 8- (40)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (41).png: GT=8, Pred=0
# 8- (42)_flipped.jpg: GT=8, Pred=0
# 8- (42)_flipped_flipped.jpg: GT=8, Pred=0
# 8- (42)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (44)_flipped.jpg: GT=8, Pred=0
# 8- (44)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (45)_flipped.jpg: GT=8, Pred=0
# 8- (45)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (46)_flipped.jpg: GT=8, Pred=0
# 8- (46)_flipped_flipped.jpg: GT=8, Pred=0
# 8- (46)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (47)_flipped.jpg: GT=8, Pred=0
# 8- (47)_flipped_flipped.jpg: GT=8, Pred=0
# 8- (47)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (48).png: GT=8, Pred=0
# 8- (49).png: GT=8, Pred=0
# 8- (49)_flipped.jpg: GT=8, Pred=0
# 8- (49)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (50).png: GT=8, Pred=0
# 8- (50)_flipped.jpg: GT=8, Pred=0
# 8- (50)_flipped_flipped.jpg: GT=8, Pred=0
# 8- (50)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (51)_flipped.jpg: GT=8, Pred=0
# 8- (51)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (52)_flipped.jpg: GT=8, Pred=0
# 8- (52)_flipped_flipped.jpg: GT=8, Pred=0
# 8- (52)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (53)_flipped.jpg: GT=8, Pred=0
# 8- (53)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (54)_flipped.jpg: GT=8, Pred=0
# 8- (54)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (55)_flipped.jpg: GT=8, Pred=0
# 8- (55)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (56).png: GT=8, Pred=0
# 8- (57)_flipped.jpg: GT=8, Pred=0
# 8- (57)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (59)_flipped.jpg: GT=8, Pred=0
# 8- (59)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (60).png: GT=8, Pred=0
# 8- (60)_flipped.jpg: GT=8, Pred=0
# 8- (60)_flipped_flipped.jpg: GT=8, Pred=0
# 8- (60)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 8- (61).png: GT=8, Pred=0
# 8- (61)_flipped.jpg: GT=8, Pred=0
# 8- (61)_flipped_flipped_flipped.jpg: GT=8, Pred=0
# 9- (1).png: GT=9, Pred=0
# 9- (10)_flipped_flipped.jpg: GT=9, Pred=0
# 9- (11).png: GT=9, Pred=0
# 9- (12).png: GT=9, Pred=0
# 9- (13).png: GT=9, Pred=0
# 9- (13)_flipped.jpg: GT=9, Pred=0
# 9- (13)_flipped_flipped_flipped.jpg: GT=9, Pred=0
# 9- (14).png: GT=9, Pred=0
# 9- (15).png: GT=9, Pred=0
# 9- (15)_flipped_flipped.jpg: GT=9, Pred=0
# 9- (16).png: GT=9, Pred=0
# 9- (19).png: GT=9, Pred=0
# 9- (2).png: GT=9, Pred=0
# 9- (20).png: GT=9, Pred=0
# 9- (22).png: GT=9, Pred=0
# 9- (23).png: GT=9, Pred=0
# 9- (24).png: GT=9, Pred=0
# 9- (24)_flipped_flipped.jpg: GT=9, Pred=0
# 9- (25).png: GT=9, Pred=0
# 9- (26).png: GT=9, Pred=0
# 9- (26)_flipped.jpg: GT=9, Pred=0
# 9- (26)_flipped_flipped.jpg: GT=9, Pred=0
# 9- (26)_flipped_flipped_flipped.jpg: GT=9, Pred=0
# 9- (27).png: GT=9, Pred=0
# 9- (27)_flipped_flipped.jpg: GT=9, Pred=0
# 9- (28).png: GT=9, Pred=0
# 9- (28)_flipped_flipped.jpg: GT=9, Pred=0
# 9- (29).png: GT=9, Pred=0
# 9- (29)_flipped_flipped.jpg: GT=9, Pred=0
# 9- (3).png: GT=9, Pred=0
# 9- (30).png: GT=9, Pred=0
# 9- (30)_flipped.jpg: GT=9, Pred=0
# 9- (30)_flipped_flipped.jpg: GT=9, Pred=0
# 9- (30)_flipped_flipped_flipped.jpg: GT=9, Pred=0
# 9- (33).png: GT=9, Pred=0
# 9- (34).png: GT=9, Pred=0
# 9- (34)_flipped.jpg: GT=9, Pred=0
# 9- (34)_flipped_flipped_flipped.jpg: GT=9, Pred=0
# 9- (35).png: GT=9, Pred=0
# 9- (36).png: GT=9, Pred=0
# 9- (36)_flipped_flipped.jpg: GT=9, Pred=0
# 9- (38).png: GT=9, Pred=0
# 9- (38)_flipped_flipped.jpg: GT=9, Pred=0
# 9- (4).png: GT=9, Pred=0
# 9- (4)_flipped.jpg: GT=9, Pred=0
# 9- (4)_flipped_flipped.jpg: GT=9, Pred=0
# 9- (4)_flipped_flipped_flipped.jpg: GT=9, Pred=0
# 9- (46).png: GT=9, Pred=0
# 9- (47).png: GT=9, Pred=0
# 9- (47)_flipped_flipped.jpg: GT=9, Pred=0
# 9- (48).png: GT=9, Pred=0
# 9- (49)_flipped_flipped.jpg: GT=9, Pred=0
# 9- (51).png: GT=9, Pred=0
# 9- (51)_flipped_flipped.jpg: GT=9, Pred=0
# 9- (52).png: GT=9, Pred=0
# 9- (52)_flipped_flipped.jpg: GT=9, Pred=0
# 9- (53).png: GT=9, Pred=0
# 9- (59).png: GT=9, Pred=0
# 9- (6).png: GT=9, Pred=0
# 9- (6)_flipped_flipped.jpg: GT=9, Pred=0
# 9- (60).png: GT=9, Pred=0
# 9- (60)_flipped_flipped.jpg: GT=9, Pred=0
# 9- (62).png: GT=9, Pred=0
# 9- (62)_flipped.jpg: GT=9, Pred=0
# 9- (62)_flipped_flipped.jpg: GT=9, Pred=0
# 9- (62)_flipped_flipped_flipped.jpg: GT=9, Pred=0
# 9- (64).png: GT=9, Pred=0
# 9- (64)_flipped.jpg: GT=9, Pred=0
# 9- (64)_flipped_flipped_flipped.jpg: GT=9, Pred=0
# 9- (65).png: GT=9, Pred=0
# 9- (66).png: GT=9, Pred=0
# 9- (67).png: GT=9, Pred=0
# 9- (67)_flipped_flipped.jpg: GT=9, Pred=0
# 9- (69).png: GT=9, Pred=0
# 9- (69)_flipped.jpg: GT=9, Pred=0
# 9- (69)_flipped_flipped.jpg: GT=9, Pred=0
# 9- (69)_flipped_flipped_flipped.jpg: GT=9, Pred=0
# 9- (7).png: GT=9, Pred=0
# 9- (70).png: GT=9, Pred=0
# 9- (72).png: GT=9, Pred=0
# 9- (72)_flipped_flipped.jpg: GT=9, Pred=0
# 9- (73).png: GT=9, Pred=0
# 9- (73)_flipped_flipped.jpg: GT=9, Pred=0
# 9- (74).png: GT=9, Pred=0
# 9- (74)_flipped_flipped.jpg: GT=9, Pred=0
# 9- (76).png: GT=9, Pred=0
